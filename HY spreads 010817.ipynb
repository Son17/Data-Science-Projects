# %%
#import libraries
import pandas as pd
pd.set_option('display.max_columns', 999)
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette()

# %%
#import data
xls_file = pd.ExcelFile('C:\\Users\\sonja tilly.ABERDEEN\\data010817.xlsx')

# %% [markdown]
# **Prep data**

# %%
#parse sheet
data = xls_file.parse('data')
data.index = data['Date']
del data['Date']
data = data.fillna(0)
data.head()
# Out:
#             FDTR Index  VIX Index  USTW$ Index  USGG10YR Index  \
# Date
# 1996-12-31        5.25      20.92      88.4869           6.418
# 1997-01-01        5.25      20.92      88.4869           6.420
# 1997-01-02        5.25      21.14      88.7042           6.514
# 1997-01-03        5.25      19.13      89.2399           6.498
# 1997-01-04        5.25      19.13      89.2399           6.498
#
#             USGG30YR Index  USGG5YR Index  USYC2Y10 Index  USYC2Y30 Index  \
# Date
# 1996-12-31           6.642          6.210           54.15            66.4
# 1997-01-01           6.641          6.210           48.45            70.6
# 1997-01-02           6.739          6.280           57.80            70.5
# 1997-01-03           6.732          6.265           54.55            78.6
# 1997-01-04           6.732          6.265           54.55            78.6
#
#             USYC5Y10 Index  USYC2Y5Y Index  CPI YOY Index  FDIDFDMO Index  \
# Date
# 1996-12-31           20.80           33.35            3.3             0.0
# 1997-01-01           14.00           34.45            3.3             0.0
# 1997-01-02           24.85           32.95            3.3             0.0
# 1997-01-03           21.05           33.50            3.3             0.0
# 1997-01-04           21.05           33.50            3.3             0.0
#
#             USURTOT Index  NFP TCH Index  USEMNCHG Index  IP CHNG Index  \
# Date
# 1996-12-31            5.4            171              89           0.64
# 1997-01-01            5.4            171              89           0.64
# 1997-01-02            5.4            171              89           0.64
# 1997-01-03            5.4            171              89           0.64
# 1997-01-04            5.4            171              89           0.64
#
#             MTIBCHNG Index  MGT2TB Index  PIDSPINX Index  NAPMPMI Index  \
# Date
# 1996-12-31             0.0          1.43          7496.1           55.2
# 1997-01-01             0.0          1.43          7496.1           55.2
# 1997-01-02             0.0          1.43          7496.1           55.2
# 1997-01-03             0.0          1.43          7496.1           55.2
# 1997-01-04             0.0          1.43          7496.1           55.2
#
#             OUTFGAF Index  USGGBE10 Index  USHBMIDX Index  CONCCONF Index  \
# Date
# 1996-12-31            8.1             0.0              55          114.25
# 1997-01-01            8.1             0.0              55          114.25
# 1997-01-02            8.1             0.0              55          114.25
# 1997-01-03            8.1             0.0              55          114.25
# 1997-01-04            8.1             0.0              55          114.25
#
#             OEUSKLAR Index  RSTAMOM Index  USTBTOT Index  FDDSGDP Index  \
# Date
# 1996-12-31         73.0711            0.4        -10.475           -1.3
# 1997-01-01         73.0711            0.4        -10.475           -1.3
# 1997-01-02         73.0711            0.4        -10.475           -1.3
# 1997-01-03         73.0711            0.4        -10.475           -1.3
# 1997-01-04         73.0711            0.4        -10.475           -1.3
#
#             M2% YOY Index  CLA Comdty  CONSSENT Index  PIDSDPS Index  \
# Date
# 1996-12-31            4.9         0.0            96.9            5.7
# 1997-01-01            4.9         0.0            96.9            5.7
# 1997-01-02            4.9         0.0            96.9            5.7
# 1997-01-03            4.9         0.0            96.9            5.7
# 1997-01-04            4.9         0.0            96.9            5.7
#
#             CICRTOT Index  ARDIMOYY Index  M1% YOY Index  SCGRRAI Index  \
# Date
# 1996-12-31         11.015            4.02           -4.1            0.0
# 1997-01-01         11.015            4.02           -4.1            0.0
# 1997-01-02         11.015            4.02           -4.1            0.0
# 1997-01-03         11.015            4.02           -4.1            0.0
# 1997-01-04         11.015            4.02           -4.1            0.0
#
#             EMB US Equity  SPE AUTO Index  SPE CARD Index  BFCIUS Index  \
# Date
# 1996-12-31            0.0             0.0             0.0         0.761
# 1997-01-01            0.0             0.0             0.0         0.779
# 1997-01-02            0.0             0.0             0.0         0.792
# 1997-01-03            0.0             0.0             0.0         0.854
# 1997-01-04            0.0             0.0             0.0         0.854
#
#             INJCJMOM Index  LEI CHNG Index  GDP CYOY Index  SLDETIGT Index  \
# Date
# 1996-12-31             7.5             0.1             4.5             0.0
# 1997-01-01             7.5             0.1             4.5             0.0
# 1997-01-02             7.5             0.1             4.5             0.0
# 1997-01-03             7.5             0.1             4.5             0.0
# 1997-01-04             7.5             0.1             4.5             0.0
#
#             SLDETGTS Index  GFSIFFND Index  XLF US Equity  XLE US Equity  \
# Date
# 1996-12-31             0.0             0.0            0.0            0.0
# 1997-01-01             0.0             0.0            0.0            0.0
# 1997-01-02             0.0             0.0            0.0            0.0
# 1997-01-03             0.0             0.0            0.0            0.0
# 1997-01-04             0.0             0.0            0.0            0.0
#
#             XLK US Equity  XLV US Equity  XLI US Equity  XLY US Equity  \
# Date
# 1996-12-31            0.0            0.0            0.0            0.0
# 1997-01-01            0.0            0.0            0.0            0.0
# 1997-01-02            0.0            0.0            0.0            0.0
# 1997-01-03            0.0            0.0            0.0            0.0
# 1997-01-04            0.0            0.0            0.0            0.0
#
#             XLB US Equity  CDX HY CDSI GEN 5Y SPRD Corp  LF98OAS Index
# Date
# 1996-12-31            0.0                           0.0           2.88
# 1997-01-01            0.0                           0.0           2.88
# 1997-01-02            0.0                           0.0           2.88
# 1997-01-03            0.0                           0.0           2.88
# 1997-01-04            0.0                           0.0           2.88

# %% [markdown]
# **Transform features**

# %%
#convert index to datetime object
data.index = pd.to_datetime(data.index)
len(data.columns)
# Out:
# 55

# %%
# these are the transformations applied to each indicator
# the transformations of the n variables create n new columns of the transformed variable which then run through the classifiers

window = [90, 180, 360]

def LevelChange (indicator, window): #calculate the monthly change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' change in '+str(window)+'ds']=data[indicator]-data[indicator].shift(days)
    
def PctChange (indicator,window): #calculate the monthly percentage change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' %change in '+str(window)+'ds']=data[indicator]/data[indicator].shift(days)-1
        
def Zscore (indicator,window):  # calculate a Z score over a number of trading days
    mean=data[indicator].rolling(window).mean()
    std=data[indicator].rolling(window).std()
    data[str(indicator)+str(window)+'zscore']=(data[indicator]-mean)/std

# %%
cols = list(data.columns)

for i in window:
    for col in cols:
        Zscore (col,i)

# %%
for i in window:
    LevelChange('FDTR Index', i)
    LevelChange('CPI YOY Index', i)
    LevelChange('IP CHNG Index', i)
    LevelChange('MGT2TB Index', i)
    LevelChange('NAPMPMI Index', i)
    LevelChange('OUTFGAF Index', i)
    LevelChange('USGGBE10 Index', i)
    LevelChange('USHBMIDX Index', i)
    LevelChange('CONCCONF Index', i)
    LevelChange('OEUSKLAR Index', i)
    LevelChange('FDDSGDP Index', i)
    LevelChange('M2% YOY Index', i)
    LevelChange('CONSSENT Index', i)
    LevelChange('PIDSDPS Index', i)
    LevelChange('CICRTOT Index', i)
    LevelChange('M1% YOY Index', i)
    LevelChange('SCGRRAI Index', i)
    LevelChange('LEI CHNG Index', i)
    LevelChange('GDP CYOY Index', i)
    LevelChange('GFSIFFND Index', i)
    LevelChange('CDX HY CDSI GEN 5Y SPRD Corp', i)
    LevelChange('LF98OAS Index', i)

# %%
for i in window:
    PctChange('VIX Index',i)
    PctChange('USTW$ Index',i)
    PctChange('USGG10YR Index',i)
    PctChange('USGG30YR Index',i)
    PctChange('USGG5YR Index',i)
    PctChange('USYC2Y10 Index',i)
    PctChange('USYC2Y30 Index',i)
    PctChange('USYC5Y10 Index',i)
    PctChange('USYC2Y5Y Index',i)
    PctChange('FDIDFDMO Index',i)
    PctChange('USEMNCHG Index',i)
    PctChange('MTIBCHNG Index',i)
    PctChange('PIDSPINX Index',i)
    PctChange('RSTAMOM Index',i)
    PctChange('USTBTOT Index',i)
    PctChange('CLA Comdty',i)
    PctChange('ARDIMOYY Index',i)
    PctChange('EMB US Equity',i)
    PctChange('SPE AUTO Index',i)
    PctChange('SPE CARD Index',i)
    PctChange('BFCIUS Index',i)
    PctChange('INJCJMOM Index',i)
    PctChange('SLDETIGT Index',i)
    PctChange('SLDETGTS Index',i)
    PctChange('XLF US Equity',i)
    PctChange('XLE US Equity',i)
    PctChange('XLK US Equity',i)
    PctChange('XLV US Equity',i)
    PctChange('XLI US Equity',i)
    PctChange('XLY US Equity',i)
    PctChange('XLB US Equity',i)

# %%
data.head(1)
# Out:
#             FDTR Index  VIX Index  USTW$ Index  USGG10YR Index  \
# Date
# 1996-12-31        5.25      20.92      88.4869           6.418
#
#             USGG30YR Index  USGG5YR Index  USYC2Y10 Index  USYC2Y30 Index  \
# Date
# 1996-12-31           6.642           6.21           54.15            66.4
#
#             USYC5Y10 Index  USYC2Y5Y Index  CPI YOY Index  FDIDFDMO Index  \
# Date
# 1996-12-31            20.8           33.35            3.3             0.0
#
#             USURTOT Index  NFP TCH Index  USEMNCHG Index  IP CHNG Index  \
# Date
# 1996-12-31            5.4            171              89           0.64
#
#             MTIBCHNG Index  MGT2TB Index  PIDSPINX Index  NAPMPMI Index  \
# Date
# 1996-12-31             0.0          1.43          7496.1           55.2
#
#             OUTFGAF Index  USGGBE10 Index  USHBMIDX Index  CONCCONF Index  \
# Date
# 1996-12-31            8.1             0.0              55          114.25
#
#             OEUSKLAR Index  RSTAMOM Index  USTBTOT Index  FDDSGDP Index  \
# Date
# 1996-12-31         73.0711            0.4        -10.475           -1.3
#
#             M2% YOY Index  CLA Comdty  CONSSENT Index  PIDSDPS Index  \
# Date
# 1996-12-31            4.9         0.0            96.9            5.7
#
#             CICRTOT Index  ARDIMOYY Index  M1% YOY Index  SCGRRAI Index  \
# Date
# 1996-12-31         11.015            4.02           -4.1            0.0
#
#             EMB US Equity  SPE AUTO Index  SPE CARD Index  BFCIUS Index  \
# Date
# 1996-12-31            0.0             0.0             0.0         0.761
#
#             INJCJMOM Index  LEI CHNG Index  GDP CYOY Index  SLDETIGT Index  \
# Date
# 1996-12-31             7.5             0.1             4.5             0.0
#
#             SLDETGTS Index  GFSIFFND Index  XLF US Equity  XLE US Equity  \
# Date
# 1996-12-31             0.0             0.0            0.0            0.0
#
#             XLK US Equity  XLV US Equity  XLI US Equity  XLY US Equity  \
# Date
# 1996-12-31            0.0            0.0            0.0            0.0
#
#             XLB US Equity  CDX HY CDSI GEN 5Y SPRD Corp  LF98OAS Index  \
# Date
# 1996-12-31            0.0                           0.0           2.88
#
#             FDTR Index90zscore  VIX Index90zscore  USTW$ Index90zscore  \
# Date
# 1996-12-31                 NaN                NaN                  NaN
#
#             USGG10YR Index90zscore  USGG30YR Index90zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             USGG5YR Index90zscore  USYC2Y10 Index90zscore  \
# Date
# 1996-12-31                    NaN                     NaN
#
#             USYC2Y30 Index90zscore  USYC5Y10 Index90zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             USYC2Y5Y Index90zscore  CPI YOY Index90zscore  \
# Date
# 1996-12-31                     NaN                    NaN
#
#             FDIDFDMO Index90zscore  USURTOT Index90zscore  \
# Date
# 1996-12-31                     NaN                    NaN
#
#             NFP TCH Index90zscore  USEMNCHG Index90zscore  \
# Date
# 1996-12-31                    NaN                     NaN
#
#             IP CHNG Index90zscore  MTIBCHNG Index90zscore  \
# Date
# 1996-12-31                    NaN                     NaN
#
#             MGT2TB Index90zscore  PIDSPINX Index90zscore  \
# Date
# 1996-12-31                   NaN                     NaN
#
#             NAPMPMI Index90zscore  OUTFGAF Index90zscore  \
# Date
# 1996-12-31                    NaN                    NaN
#
#             USGGBE10 Index90zscore  USHBMIDX Index90zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             CONCCONF Index90zscore  OEUSKLAR Index90zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             RSTAMOM Index90zscore  USTBTOT Index90zscore  \
# Date
# 1996-12-31                    NaN                    NaN
#
#             FDDSGDP Index90zscore  M2% YOY Index90zscore  CLA Comdty90zscore  \
# Date
# 1996-12-31                    NaN                    NaN                 NaN
#
#             CONSSENT Index90zscore  PIDSDPS Index90zscore  \
# Date
# 1996-12-31                     NaN                    NaN
#
#             CICRTOT Index90zscore  ARDIMOYY Index90zscore  \
# Date
# 1996-12-31                    NaN                     NaN
#
#             M1% YOY Index90zscore  SCGRRAI Index90zscore  \
# Date
# 1996-12-31                    NaN                    NaN
#
#             EMB US Equity90zscore  SPE AUTO Index90zscore  \
# Date
# 1996-12-31                    NaN                     NaN
#
#             SPE CARD Index90zscore  BFCIUS Index90zscore  \
# Date
# 1996-12-31                     NaN                   NaN
#
#             INJCJMOM Index90zscore  LEI CHNG Index90zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             GDP CYOY Index90zscore  SLDETIGT Index90zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             SLDETGTS Index90zscore  GFSIFFND Index90zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             XLF US Equity90zscore  XLE US Equity90zscore  \
# Date
# 1996-12-31                    NaN                    NaN
#
#             XLK US Equity90zscore  XLV US Equity90zscore  \
# Date
# 1996-12-31                    NaN                    NaN
#
#             XLI US Equity90zscore  XLY US Equity90zscore  \
# Date
# 1996-12-31                    NaN                    NaN
#
#             XLB US Equity90zscore  CDX HY CDSI GEN 5Y SPRD Corp90zscore  \
# Date
# 1996-12-31                    NaN                                   NaN
#
#             LF98OAS Index90zscore  FDTR Index180zscore  VIX Index180zscore  \
# Date
# 1996-12-31                    NaN                  NaN                 NaN
#
#             USTW$ Index180zscore  USGG10YR Index180zscore  \
# Date
# 1996-12-31                   NaN                      NaN
#
#             USGG30YR Index180zscore  USGG5YR Index180zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             USYC2Y10 Index180zscore  USYC2Y30 Index180zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             USYC5Y10 Index180zscore  USYC2Y5Y Index180zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             CPI YOY Index180zscore  FDIDFDMO Index180zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             USURTOT Index180zscore  NFP TCH Index180zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             USEMNCHG Index180zscore  IP CHNG Index180zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             MTIBCHNG Index180zscore  MGT2TB Index180zscore  \
# Date
# 1996-12-31                      NaN                    NaN
#
#             PIDSPINX Index180zscore  NAPMPMI Index180zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             OUTFGAF Index180zscore  USGGBE10 Index180zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             USHBMIDX Index180zscore  CONCCONF Index180zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             OEUSKLAR Index180zscore  RSTAMOM Index180zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             USTBTOT Index180zscore  FDDSGDP Index180zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             M2% YOY Index180zscore  CLA Comdty180zscore  \
# Date
# 1996-12-31                     NaN                  NaN
#
#             CONSSENT Index180zscore  PIDSDPS Index180zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             CICRTOT Index180zscore  ARDIMOYY Index180zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             M1% YOY Index180zscore  SCGRRAI Index180zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             EMB US Equity180zscore  SPE AUTO Index180zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             SPE CARD Index180zscore  BFCIUS Index180zscore  \
# Date
# 1996-12-31                      NaN                    NaN
#
#             INJCJMOM Index180zscore  LEI CHNG Index180zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             GDP CYOY Index180zscore  SLDETIGT Index180zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             SLDETGTS Index180zscore  GFSIFFND Index180zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             XLF US Equity180zscore  XLE US Equity180zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             XLK US Equity180zscore  XLV US Equity180zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             XLI US Equity180zscore  XLY US Equity180zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             XLB US Equity180zscore  CDX HY CDSI GEN 5Y SPRD Corp180zscore  \
# Date
# 1996-12-31                     NaN                                    NaN
#
#             LF98OAS Index180zscore  FDTR Index360zscore  VIX Index360zscore  \
# Date
# 1996-12-31                     NaN                  NaN                 NaN
#
#             USTW$ Index360zscore  USGG10YR Index360zscore  \
# Date
# 1996-12-31                   NaN                      NaN
#
#             USGG30YR Index360zscore  USGG5YR Index360zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             USYC2Y10 Index360zscore  USYC2Y30 Index360zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             USYC5Y10 Index360zscore  USYC2Y5Y Index360zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             CPI YOY Index360zscore  FDIDFDMO Index360zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             USURTOT Index360zscore  NFP TCH Index360zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             USEMNCHG Index360zscore  IP CHNG Index360zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             MTIBCHNG Index360zscore  MGT2TB Index360zscore  \
# Date
# 1996-12-31                      NaN                    NaN
#
#             PIDSPINX Index360zscore  NAPMPMI Index360zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             OUTFGAF Index360zscore  USGGBE10 Index360zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             USHBMIDX Index360zscore  CONCCONF Index360zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             OEUSKLAR Index360zscore  RSTAMOM Index360zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             USTBTOT Index360zscore  FDDSGDP Index360zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             M2% YOY Index360zscore  CLA Comdty360zscore  \
# Date
# 1996-12-31                     NaN                  NaN
#
#             CONSSENT Index360zscore  PIDSDPS Index360zscore  \
# Date
# 1996-12-31                      NaN                     NaN
#
#             CICRTOT Index360zscore  ARDIMOYY Index360zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             M1% YOY Index360zscore  SCGRRAI Index360zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             EMB US Equity360zscore  SPE AUTO Index360zscore  \
# Date
# 1996-12-31                     NaN                      NaN
#
#             SPE CARD Index360zscore  BFCIUS Index360zscore  \
# Date
# 1996-12-31                      NaN                    NaN
#
#             INJCJMOM Index360zscore  LEI CHNG Index360zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             GDP CYOY Index360zscore  SLDETIGT Index360zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             SLDETGTS Index360zscore  GFSIFFND Index360zscore  \
# Date
# 1996-12-31                      NaN                      NaN
#
#             XLF US Equity360zscore  XLE US Equity360zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             XLK US Equity360zscore  XLV US Equity360zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             XLI US Equity360zscore  XLY US Equity360zscore  \
# Date
# 1996-12-31                     NaN                     NaN
#
#             XLB US Equity360zscore  CDX HY CDSI GEN 5Y SPRD Corp360zscore  \
# Date
# 1996-12-31                     NaN                                    NaN
#
#             LF98OAS Index360zscore  FDTR Index change in 90ds  \
# Date
# 1996-12-31                     NaN                        NaN
#
#             CPI YOY Index change in 90ds  IP CHNG Index change in 90ds  \
# Date
# 1996-12-31                           NaN                           NaN
#
#             MGT2TB Index change in 90ds  NAPMPMI Index change in 90ds  \
# Date
# 1996-12-31                          NaN                           NaN
#
#             OUTFGAF Index change in 90ds  USGGBE10 Index change in 90ds  \
# Date
# 1996-12-31                           NaN                            NaN
#
#             USHBMIDX Index change in 90ds  CONCCONF Index change in 90ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             OEUSKLAR Index change in 90ds  FDDSGDP Index change in 90ds  \
# Date
# 1996-12-31                            NaN                           NaN
#
#             M2% YOY Index change in 90ds  CONSSENT Index change in 90ds  \
# Date
# 1996-12-31                           NaN                            NaN
#
#             PIDSDPS Index change in 90ds  CICRTOT Index change in 90ds  \
# Date
# 1996-12-31                           NaN                           NaN
#
#             M1% YOY Index change in 90ds  SCGRRAI Index change in 90ds  \
# Date
# 1996-12-31                           NaN                           NaN
#
#             LEI CHNG Index change in 90ds  GDP CYOY Index change in 90ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             GFSIFFND Index change in 90ds  \
# Date
# 1996-12-31                            NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 90ds  \
# Date
# 1996-12-31                                          NaN
#
#             LF98OAS Index change in 90ds  FDTR Index change in 180ds  \
# Date
# 1996-12-31                           NaN                         NaN
#
#             CPI YOY Index change in 180ds  IP CHNG Index change in 180ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             MGT2TB Index change in 180ds  NAPMPMI Index change in 180ds  \
# Date
# 1996-12-31                           NaN                            NaN
#
#             OUTFGAF Index change in 180ds  USGGBE10 Index change in 180ds  \
# Date
# 1996-12-31                            NaN                             NaN
#
#             USHBMIDX Index change in 180ds  CONCCONF Index change in 180ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             OEUSKLAR Index change in 180ds  FDDSGDP Index change in 180ds  \
# Date
# 1996-12-31                             NaN                            NaN
#
#             M2% YOY Index change in 180ds  CONSSENT Index change in 180ds  \
# Date
# 1996-12-31                            NaN                             NaN
#
#             PIDSDPS Index change in 180ds  CICRTOT Index change in 180ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             M1% YOY Index change in 180ds  SCGRRAI Index change in 180ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             LEI CHNG Index change in 180ds  GDP CYOY Index change in 180ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             GFSIFFND Index change in 180ds  \
# Date
# 1996-12-31                             NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 180ds  \
# Date
# 1996-12-31                                           NaN
#
#             LF98OAS Index change in 180ds  FDTR Index change in 360ds  \
# Date
# 1996-12-31                            NaN                         NaN
#
#             CPI YOY Index change in 360ds  IP CHNG Index change in 360ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             MGT2TB Index change in 360ds  NAPMPMI Index change in 360ds  \
# Date
# 1996-12-31                           NaN                            NaN
#
#             OUTFGAF Index change in 360ds  USGGBE10 Index change in 360ds  \
# Date
# 1996-12-31                            NaN                             NaN
#
#             USHBMIDX Index change in 360ds  CONCCONF Index change in 360ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             OEUSKLAR Index change in 360ds  FDDSGDP Index change in 360ds  \
# Date
# 1996-12-31                             NaN                            NaN
#
#             M2% YOY Index change in 360ds  CONSSENT Index change in 360ds  \
# Date
# 1996-12-31                            NaN                             NaN
#
#             PIDSDPS Index change in 360ds  CICRTOT Index change in 360ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             M1% YOY Index change in 360ds  SCGRRAI Index change in 360ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             LEI CHNG Index change in 360ds  GDP CYOY Index change in 360ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             GFSIFFND Index change in 360ds  \
# Date
# 1996-12-31                             NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 360ds  \
# Date
# 1996-12-31                                           NaN
#
#             LF98OAS Index change in 360ds  VIX Index %change in 90ds  \
# Date
# 1996-12-31                            NaN                        NaN
#
#             USTW$ Index %change in 90ds  USGG10YR Index %change in 90ds  \
# Date
# 1996-12-31                          NaN                             NaN
#
#             USGG30YR Index %change in 90ds  USGG5YR Index %change in 90ds  \
# Date
# 1996-12-31                             NaN                            NaN
#
#             USYC2Y10 Index %change in 90ds  USYC2Y30 Index %change in 90ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             USYC5Y10 Index %change in 90ds  USYC2Y5Y Index %change in 90ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             FDIDFDMO Index %change in 90ds  USEMNCHG Index %change in 90ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             MTIBCHNG Index %change in 90ds  PIDSPINX Index %change in 90ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             RSTAMOM Index %change in 90ds  USTBTOT Index %change in 90ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             CLA Comdty %change in 90ds  ARDIMOYY Index %change in 90ds  \
# Date
# 1996-12-31                         NaN                             NaN
#
#             EMB US Equity %change in 90ds  SPE AUTO Index %change in 90ds  \
# Date
# 1996-12-31                            NaN                             NaN
#
#             SPE CARD Index %change in 90ds  BFCIUS Index %change in 90ds  \
# Date
# 1996-12-31                             NaN                           NaN
#
#             INJCJMOM Index %change in 90ds  SLDETIGT Index %change in 90ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             SLDETGTS Index %change in 90ds  XLF US Equity %change in 90ds  \
# Date
# 1996-12-31                             NaN                            NaN
#
#             XLE US Equity %change in 90ds  XLK US Equity %change in 90ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             XLV US Equity %change in 90ds  XLI US Equity %change in 90ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             XLY US Equity %change in 90ds  XLB US Equity %change in 90ds  \
# Date
# 1996-12-31                            NaN                            NaN
#
#             VIX Index %change in 180ds  USTW$ Index %change in 180ds  \
# Date
# 1996-12-31                         NaN                           NaN
#
#             USGG10YR Index %change in 180ds  USGG30YR Index %change in 180ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             USGG5YR Index %change in 180ds  USYC2Y10 Index %change in 180ds  \
# Date
# 1996-12-31                             NaN                              NaN
#
#             USYC2Y30 Index %change in 180ds  USYC5Y10 Index %change in 180ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             USYC2Y5Y Index %change in 180ds  FDIDFDMO Index %change in 180ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             USEMNCHG Index %change in 180ds  MTIBCHNG Index %change in 180ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             PIDSPINX Index %change in 180ds  RSTAMOM Index %change in 180ds  \
# Date
# 1996-12-31                              NaN                             NaN
#
#             USTBTOT Index %change in 180ds  CLA Comdty %change in 180ds  \
# Date
# 1996-12-31                             NaN                          NaN
#
#             ARDIMOYY Index %change in 180ds  EMB US Equity %change in 180ds  \
# Date
# 1996-12-31                              NaN                             NaN
#
#             SPE AUTO Index %change in 180ds  SPE CARD Index %change in 180ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             BFCIUS Index %change in 180ds  INJCJMOM Index %change in 180ds  \
# Date
# 1996-12-31                            NaN                              NaN
#
#             SLDETIGT Index %change in 180ds  SLDETGTS Index %change in 180ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             XLF US Equity %change in 180ds  XLE US Equity %change in 180ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             XLK US Equity %change in 180ds  XLV US Equity %change in 180ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             XLI US Equity %change in 180ds  XLY US Equity %change in 180ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             XLB US Equity %change in 180ds  VIX Index %change in 360ds  \
# Date
# 1996-12-31                             NaN                         NaN
#
#             USTW$ Index %change in 360ds  USGG10YR Index %change in 360ds  \
# Date
# 1996-12-31                           NaN                              NaN
#
#             USGG30YR Index %change in 360ds  USGG5YR Index %change in 360ds  \
# Date
# 1996-12-31                              NaN                             NaN
#
#             USYC2Y10 Index %change in 360ds  USYC2Y30 Index %change in 360ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             USYC5Y10 Index %change in 360ds  USYC2Y5Y Index %change in 360ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             FDIDFDMO Index %change in 360ds  USEMNCHG Index %change in 360ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             MTIBCHNG Index %change in 360ds  PIDSPINX Index %change in 360ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             RSTAMOM Index %change in 360ds  USTBTOT Index %change in 360ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             CLA Comdty %change in 360ds  ARDIMOYY Index %change in 360ds  \
# Date
# 1996-12-31                          NaN                              NaN
#
#             EMB US Equity %change in 360ds  SPE AUTO Index %change in 360ds  \
# Date
# 1996-12-31                             NaN                              NaN
#
#             SPE CARD Index %change in 360ds  BFCIUS Index %change in 360ds  \
# Date
# 1996-12-31                              NaN                            NaN
#
#             INJCJMOM Index %change in 360ds  SLDETIGT Index %change in 360ds  \
# Date
# 1996-12-31                              NaN                              NaN
#
#             SLDETGTS Index %change in 360ds  XLF US Equity %change in 360ds  \
# Date
# 1996-12-31                              NaN                             NaN
#
#             XLE US Equity %change in 360ds  XLK US Equity %change in 360ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             XLV US Equity %change in 360ds  XLI US Equity %change in 360ds  \
# Date
# 1996-12-31                             NaN                             NaN
#
#             XLY US Equity %change in 360ds  XLB US Equity %change in 360ds
# Date
# 1996-12-31                             NaN                             NaN

# %%
#address data lags

def Shift(indicator, d):
    indicator.shift(d)
        return


#df[['CPI YOY Index','FDIDFDMO Index','USURTOT Index','NFP TCH Index', 'USEMNCHG Index',\
 #  'IP CHNG Index', 'MTIBCHNG Index', 'MGT2TB Index', 'OUTFGAF Index', 'USHBMIDX Index',\
  # 'CONCCONF Index','RSTAMOM Index', 'USTBTOT Index', 'CONSSENT Index', 'CICRTOT Index',\
   #'SPE AUTO Index', 'SPE CARD Index', 'GDP CYOY Index']].shift(3).fillna(0.0000001)

df['CPI YOY Index'] = df['CPI YOY Index'].shift(3)
df['FDIDFDMO Index'] = df['FDIDFDMO Index'].shift(3)
df['NFP TCH Index'] = df['NFP TCH Index'].shift(3)
df['USEMNCHG Index'] = df['USEMNCHG Index'].shift(3)
df['IP CHNG Index'] = df['IP CHNG Index'].shift(3)
df['MTIBCHNG Index'] = df['MTIBCHNG Index'].shift(3)
df['MGT2TB Index'] = df['MGT2TB Index'].shift(3)
df['OUTFGAF Index'] = df['OUTFGAF Index'].shift(3)
df['USHBMIDX Index'] = df['USHBMIDX Index'].shift(3)
df['CONCCONF Index'] = df['CONCCONF Index'].shift(3)
df['RSTAMOM Index'] = df['RSTAMOM Index'].shift(3)
df['USTBTOT Index'] = df['USTBTOT Index'].shift(3)
df['CONSSENT Index'] = df['CONSSENT Index'].shift(3)
df['CICRTOT Index'] = df['CICRTOT Index'].shift(3)
df['SPE AUTO Index'] = df['SPE AUTO Index'].shift(3)
df['GDP CYOY Index'] = df['GDP CYOY Index'].shift(3)

df.head()

# %%
#parse sheet
tgt = xls_file.parse('tgt')
y = np.array(tgt).ravel()

# %%
# For each variable in X, calculate VIF and save in dataframe

from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["vif"] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
vif["features"] = df.columns
vif = (vif[vif.vif >= 5])
vif

# %%
#drop features with infinite or above 5 variance inflation factor

X.drop(X[['USGG10YR% Index_zscore', 'USGG30YR% Index_zscore', 'USGG5YR% Index_zscore',\
                  'USTBTOT% Index_zscore', 'GDPCTOT% Index_zscore',\
                  'GPDITOC% Index_zscore', 'GDP CQOQ Index_zscore']], axis=1, inplace=True)

# %%
#split dataset

X_train = X[:196]
y_train = y[:196]
X_test = X[196:]
y_test = y[196:]
X_train.head()

# %%
#try Lasso regression

from sklearn import linear_model

lasso = linear_model.Lasso(alpha=0.21, fit_intercept=False, normalize=False, precompute=False,\
                           copy_X=True, max_iter=1000, tol=0.01, warm_start=False,\
                           positive=False, random_state=42, selection='cyclic')
lasso.fit(X_train, y_train)
lasso.score(X_test,y_test)

# %%
#try RandomForests

from sklearn.ensemble import RandomForestRegressor

tree = RandomForestRegressor(n_estimators=30, criterion='mse',
                            max_depth=4, min_samples_split=2, 
                            min_samples_leaf=1,
                            min_weight_fraction_leaf=0.30,
                            max_features='auto',
                            max_leaf_nodes=None,
                            min_impurity_split=1e-07,
                            bootstrap=True, oob_score=False, n_jobs=-1,
                            random_state=None, verbose=0,
                            warm_start=False)
tree.fit(X_train, y_train)
tree.score(X_test, y_test)
