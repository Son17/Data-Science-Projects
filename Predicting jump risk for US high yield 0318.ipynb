# %%
#import libraries
import pandas as pd
pd.set_option('display.max_columns', 999)
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette("hls", 20)

# %%
#import data
xls_file = pd.ExcelFile('C:\\Users\\sonja tilly.ABERDEEN\\data270218.xlsx')

# %% [markdown]
# **Prep data**

# %%
#parse sheet
data = xls_file.parse('data_v_2')
data.index = data['Date']
del data['Date']
data.shape
# Out:
# (7364, 33)

# %%
data.columns
# Out:
# Index([u'FDTR Index', u'VIX Index', u'USGG5YR Index', u'USYC2Y10 Index',
#        u'CPI YOY Index', u'USURTOT Index', u'OUTFGAF Index', u'CLA Comdty',
#        u'CONSSENT Index', u'SCGRRAI Index', u'EMB US Equity',
#        u'SPE AUTO Index', u'SPE CARD Index', u'LEI CHNG Index',
#        u'GFSIFFND Index', u'XLF US Equity', u'XLE US Equity', u'XLK US Equity',
#        u'XLV US Equity', u'XLI US Equity', u'XLY US Equity', u'XLB US Equity',
#        u'PCUSEQTR Index', u'GFSIRLIQ Index', u'CIGMGRAM Index', u'SPX Index',
#        u'US0003M Index', u'AHE YOY% Index', u'NHSPSTOT Index',
#        u'NAPMNEWO Index', u'CPTICHNG Index', u'USGGBE05 Index',
#        u'LF98OAS Index'],
#       dtype='object')

# %%
#address data lags

data['USURTOT Index'] = data['USURTOT Index'].shift(5)
data['CPI YOY Index'] = data['CPI YOY Index'].shift(10)
data['AHE YOY% Index'] = data['AHE YOY% Index'].shift(10)
data['OUTFGAF Index'] = data['OUTFGAF Index'].shift(15)
data['CONSSENT Index'] = data['CONSSENT Index'].shift(15)
data['NHSPSTOT Index'] = data['NHSPSTOT Index'].shift(15)
data['CPTICHNG Index'] = data['CPTICHNG Index'].shift(15)
data['LEI CHNG Index'] = data['LEI CHNG Index'].shift(20)
data['SPE AUTO Index'] = data['SPE AUTO Index'].shift(30)
data['NAPMNEWO Index'] = data['NAPMNEWO Index'].shift(30)

data = data.fillna(0)
data.shape
# Out:
# (7364, 33)

# %% [markdown]
# **Transform features**

# %%
#convert index to datetime object
data.index = pd.to_datetime(data.index)

# %%
# these are the transformations applied to each indicator
# the transformations of the n variables create n new columns of the transformed variable which then run through the classifiers
# add zscore formula to LevelChange and PctChange

from scipy import stats

window = [30, 90, 365, 1095, 1825]
window2 = [365, 1095, 1825]

def LevelChange (indicator, window): #calculate the monthly change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' change in '+str(window)+'ds']=data[indicator]-data[indicator].shift(days)
    #data[str(indicator)+' change in '+str(window)+'ds' +'zscore']=stats.zscore(data[indicator], axis=None)
    
def PctChange (indicator,window): #calculate the monthly percentage change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' %change in '+str(window)+'ds']=data[indicator]/data[indicator].shift(days)-1
    #data[str(indicator)+' change in '+str(window)+'ds' +'zscore']=stats.zscore(data[indicator], axis=None)
    
def Zscore (indicator,window):  # calculate a Z score over a number of trading days
    mean=data[indicator].rolling(window).mean()
    std=data[indicator].rolling(window).std()
    data[str(indicator)+str(window)+'zscore']=(data[indicator]-mean)/std

# %%
# calculate ratios for equity subsector indices

data['XLF US Equity_ratio'] = data['XLF US Equity']/data['SPX Index']
data['XLE US Equity_ratio'] = data['XLE US Equity']/data['SPX Index']
data['XLK US Equity_ratio'] = data['XLK US Equity']/data['SPX Index']
data['XLV US Equity_ratio'] = data['XLV US Equity']/data['SPX Index']
data['XLI US Equity_ratio'] = data['XLI US Equity']/data['SPX Index']
data['XLY US Equity_ratio'] = data['XLY US Equity']/data['SPX Index']
data['XLB US Equity_ratio'] = data['XLB US Equity']/data['SPX Index']

data = data.drop(data[['XLF US Equity', 'XLE US Equity', 'XLK US Equity', 'XLV US Equity',
                  'XLI US Equity', 'XLY US Equity', 'XLB US Equity']], axis=1)

# %%
# calculate z-scores for daily data

cols1 = ['CLA Comdty', 'SCGRRAI Index', 'EMB US Equity', 'GFSIRLIQ Index', 'CIGMGRAM Index', 
        'FDTR Index', 'VIX Index', 'USGG5YR Index', 'USYC2Y10 Index', 'GFSIFFND Index',
        'PCUSEQTR Index', 'SPX Index', 'US0003M Index', 'USGGBE05 Index',
        'XLF US Equity_ratio', 'XLE US Equity_ratio', 'XLK US Equity_ratio',
         'XLV US Equity_ratio', 'XLI US Equity_ratio', 'XLY US Equity_ratio', 'XLB US Equity_ratio']

for i in window:
    for col in cols1:
        Zscore (col,i)

# %%
# calculate z-scores for monthly data

cols2 = ['USURTOT Index', 'CPI YOY Index', 'AHE YOY% Index', 'OUTFGAF Index', 'CONSSENT Index',
        'NHSPSTOT Index', 'CPTICHNG Index', 'LEI CHNG Index', 'SPE AUTO Index',
        'NAPMNEWO Index']

for i in window2:
    for col in cols2:
        Zscore (col,i)

# %%
for i in window:
    LevelChange('USURTOT Index', i)
    LevelChange('CPI YOY Index', i)
    LevelChange('AHE YOY% Index', i)
    LevelChange('OUTFGAF Index', i)
    LevelChange('CONSSENT Index', i)
    LevelChange('NHSPSTOT Index', i)
    LevelChange('CPTICHNG Index', i)
    LevelChange('LEI CHNG Index', i)
    LevelChange('SPE AUTO Index', i)
    LevelChange('NAPMNEWO Index', i)
    LevelChange('FDTR Index', i)
    LevelChange('VIX Index', i)
    LevelChange('USGG5YR Index', i)
    LevelChange('USYC2Y10 Index', i)
    LevelChange('GFSIFFND Index', i)
    LevelChange('PCUSEQTR Index', i)
    LevelChange('US0003M Index', i)
    LevelChange('USGGBE05 Index', i)
    LevelChange('LF98OAS Index', i)
    LevelChange('XLF US Equity_ratio', i)
    LevelChange('XLE US Equity_ratio', i)
    LevelChange('XLK US Equity_ratio', i)
    LevelChange('XLV US Equity_ratio', i)
    LevelChange('XLI US Equity_ratio', i)
    LevelChange('XLY US Equity_ratio', i)
    LevelChange('XLB US Equity_ratio', i)

# %%
for i in window:
    PctChange('CPI YOY Index',i)
    PctChange('CLA Comdty',i)
    PctChange('EMB US Equity',i)
    PctChange('SCGRRAI Index',i)
    PctChange('GFSIRLIQ Index',i)
    PctChange('CIGMGRAM Index',i)
    PctChange('SPX Index',i)

# %%
data.head(2)
# Out:
#             FDTR Index  VIX Index  USGG5YR Index  USYC2Y10 Index  \
# Date
# 1998-01-01         5.5      24.01          5.707            18.2
# 1998-01-02         5.5      23.42          5.605            19.5
#
#             CPI YOY Index  USURTOT Index  OUTFGAF Index  CLA Comdty  \
# Date
# 1998-01-01            0.0            0.0            0.0         0.0
# 1998-01-02            0.0            0.0            0.0         0.0
#
#             CONSSENT Index  SCGRRAI Index  EMB US Equity  SPE AUTO Index  \
# Date
# 1998-01-01             0.0            0.0            0.0             0.0
# 1998-01-02             0.0            0.0            0.0             0.0
#
#             SPE CARD Index  LEI CHNG Index  GFSIFFND Index  PCUSEQTR Index  \
# Date
# 1998-01-01             0.0             0.0             0.0            0.46
# 1998-01-02             0.0             0.0             0.0            0.49
#
#             GFSIRLIQ Index  CIGMGRAM Index  SPX Index  US0003M Index  \
# Date
# 1998-01-01             0.0             0.0     970.43        5.81250
# 1998-01-02             0.0             0.0     975.04        5.80859
#
#             AHE YOY% Index  NHSPSTOT Index  NAPMNEWO Index  CPTICHNG Index  \
# Date
# 1998-01-01             0.0             0.0             0.0             0.0
# 1998-01-02             0.0             0.0             0.0             0.0
#
#             USGGBE05 Index  LF98OAS Index  XLF US Equity_ratio  \
# Date
# 1998-01-01             0.0           2.88                  0.0
# 1998-01-02             0.0           2.88                  0.0
#
#             XLE US Equity_ratio  XLK US Equity_ratio  XLV US Equity_ratio  \
# Date
# 1998-01-01                  0.0                  0.0                  0.0
# 1998-01-02                  0.0                  0.0                  0.0
#
#             XLI US Equity_ratio  XLY US Equity_ratio  XLB US Equity_ratio  \
# Date
# 1998-01-01                  0.0                  0.0                  0.0
# 1998-01-02                  0.0                  0.0                  0.0
#
#             CLA Comdty30zscore  SCGRRAI Index30zscore  EMB US Equity30zscore  \
# Date
# 1998-01-01                 NaN                    NaN                    NaN
# 1998-01-02                 NaN                    NaN                    NaN
#
#             GFSIRLIQ Index30zscore  CIGMGRAM Index30zscore  \
# Date
# 1998-01-01                     NaN                     NaN
# 1998-01-02                     NaN                     NaN
#
#             FDTR Index30zscore  VIX Index30zscore  USGG5YR Index30zscore  \
# Date
# 1998-01-01                 NaN                NaN                    NaN
# 1998-01-02                 NaN                NaN                    NaN
#
#             USYC2Y10 Index30zscore  GFSIFFND Index30zscore  \
# Date
# 1998-01-01                     NaN                     NaN
# 1998-01-02                     NaN                     NaN
#
#             PCUSEQTR Index30zscore  SPX Index30zscore  US0003M Index30zscore  \
# Date
# 1998-01-01                     NaN                NaN                    NaN
# 1998-01-02                     NaN                NaN                    NaN
#
#             USGGBE05 Index30zscore  XLF US Equity_ratio30zscore  \
# Date
# 1998-01-01                     NaN                          NaN
# 1998-01-02                     NaN                          NaN
#
#             XLE US Equity_ratio30zscore  XLK US Equity_ratio30zscore  \
# Date
# 1998-01-01                          NaN                          NaN
# 1998-01-02                          NaN                          NaN
#
#             XLV US Equity_ratio30zscore  XLI US Equity_ratio30zscore  \
# Date
# 1998-01-01                          NaN                          NaN
# 1998-01-02                          NaN                          NaN
#
#             XLY US Equity_ratio30zscore  XLB US Equity_ratio30zscore  \
# Date
# 1998-01-01                          NaN                          NaN
# 1998-01-02                          NaN                          NaN
#
#             CLA Comdty90zscore  SCGRRAI Index90zscore  EMB US Equity90zscore  \
# Date
# 1998-01-01                 NaN                    NaN                    NaN
# 1998-01-02                 NaN                    NaN                    NaN
#
#             GFSIRLIQ Index90zscore  CIGMGRAM Index90zscore  \
# Date
# 1998-01-01                     NaN                     NaN
# 1998-01-02                     NaN                     NaN
#
#             FDTR Index90zscore  VIX Index90zscore  USGG5YR Index90zscore  \
# Date
# 1998-01-01                 NaN                NaN                    NaN
# 1998-01-02                 NaN                NaN                    NaN
#
#             USYC2Y10 Index90zscore  GFSIFFND Index90zscore  \
# Date
# 1998-01-01                     NaN                     NaN
# 1998-01-02                     NaN                     NaN
#
#             PCUSEQTR Index90zscore  SPX Index90zscore  US0003M Index90zscore  \
# Date
# 1998-01-01                     NaN                NaN                    NaN
# 1998-01-02                     NaN                NaN                    NaN
#
#             USGGBE05 Index90zscore  XLF US Equity_ratio90zscore  \
# Date
# 1998-01-01                     NaN                          NaN
# 1998-01-02                     NaN                          NaN
#
#             XLE US Equity_ratio90zscore  XLK US Equity_ratio90zscore  \
# Date
# 1998-01-01                          NaN                          NaN
# 1998-01-02                          NaN                          NaN
#
#             XLV US Equity_ratio90zscore  XLI US Equity_ratio90zscore  \
# Date
# 1998-01-01                          NaN                          NaN
# 1998-01-02                          NaN                          NaN
#
#             XLY US Equity_ratio90zscore  XLB US Equity_ratio90zscore  \
# Date
# 1998-01-01                          NaN                          NaN
# 1998-01-02                          NaN                          NaN
#
#             CLA Comdty365zscore  SCGRRAI Index365zscore  \
# Date
# 1998-01-01                  NaN                     NaN
# 1998-01-02                  NaN                     NaN
#
#             EMB US Equity365zscore  GFSIRLIQ Index365zscore  \
# Date
# 1998-01-01                     NaN                      NaN
# 1998-01-02                     NaN                      NaN
#
#             CIGMGRAM Index365zscore  FDTR Index365zscore  VIX Index365zscore  \
# Date
# 1998-01-01                      NaN                  NaN                 NaN
# 1998-01-02                      NaN                  NaN                 NaN
#
#             USGG5YR Index365zscore  USYC2Y10 Index365zscore  \
# Date
# 1998-01-01                     NaN                      NaN
# 1998-01-02                     NaN                      NaN
#
#             GFSIFFND Index365zscore  PCUSEQTR Index365zscore  \
# Date
# 1998-01-01                      NaN                      NaN
# 1998-01-02                      NaN                      NaN
#
#             SPX Index365zscore  US0003M Index365zscore  \
# Date
# 1998-01-01                 NaN                     NaN
# 1998-01-02                 NaN                     NaN
#
#             USGGBE05 Index365zscore  XLF US Equity_ratio365zscore  \
# Date
# 1998-01-01                      NaN                           NaN
# 1998-01-02                      NaN                           NaN
#
#             XLE US Equity_ratio365zscore  XLK US Equity_ratio365zscore  \
# Date
# 1998-01-01                           NaN                           NaN
# 1998-01-02                           NaN                           NaN
#
#             XLV US Equity_ratio365zscore  XLI US Equity_ratio365zscore  \
# Date
# 1998-01-01                           NaN                           NaN
# 1998-01-02                           NaN                           NaN
#
#             XLY US Equity_ratio365zscore  XLB US Equity_ratio365zscore  \
# Date
# 1998-01-01                           NaN                           NaN
# 1998-01-02                           NaN                           NaN
#
#             CLA Comdty1095zscore  SCGRRAI Index1095zscore  \
# Date
# 1998-01-01                   NaN                      NaN
# 1998-01-02                   NaN                      NaN
#
#             EMB US Equity1095zscore  GFSIRLIQ Index1095zscore  \
# Date
# 1998-01-01                      NaN                       NaN
# 1998-01-02                      NaN                       NaN
#
#             CIGMGRAM Index1095zscore  FDTR Index1095zscore  \
# Date
# 1998-01-01                       NaN                   NaN
# 1998-01-02                       NaN                   NaN
#
#             VIX Index1095zscore  USGG5YR Index1095zscore  \
# Date
# 1998-01-01                  NaN                      NaN
# 1998-01-02                  NaN                      NaN
#
#             USYC2Y10 Index1095zscore  GFSIFFND Index1095zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             PCUSEQTR Index1095zscore  SPX Index1095zscore  \
# Date
# 1998-01-01                       NaN                  NaN
# 1998-01-02                       NaN                  NaN
#
#             US0003M Index1095zscore  USGGBE05 Index1095zscore  \
# Date
# 1998-01-01                      NaN                       NaN
# 1998-01-02                      NaN                       NaN
#
#             XLF US Equity_ratio1095zscore  XLE US Equity_ratio1095zscore  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             XLK US Equity_ratio1095zscore  XLV US Equity_ratio1095zscore  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             XLI US Equity_ratio1095zscore  XLY US Equity_ratio1095zscore  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             XLB US Equity_ratio1095zscore  CLA Comdty1825zscore  \
# Date
# 1998-01-01                            NaN                   NaN
# 1998-01-02                            NaN                   NaN
#
#             SCGRRAI Index1825zscore  EMB US Equity1825zscore  \
# Date
# 1998-01-01                      NaN                      NaN
# 1998-01-02                      NaN                      NaN
#
#             GFSIRLIQ Index1825zscore  CIGMGRAM Index1825zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             FDTR Index1825zscore  VIX Index1825zscore  \
# Date
# 1998-01-01                   NaN                  NaN
# 1998-01-02                   NaN                  NaN
#
#             USGG5YR Index1825zscore  USYC2Y10 Index1825zscore  \
# Date
# 1998-01-01                      NaN                       NaN
# 1998-01-02                      NaN                       NaN
#
#             GFSIFFND Index1825zscore  PCUSEQTR Index1825zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             SPX Index1825zscore  US0003M Index1825zscore  \
# Date
# 1998-01-01                  NaN                      NaN
# 1998-01-02                  NaN                      NaN
#
#             USGGBE05 Index1825zscore  XLF US Equity_ratio1825zscore  \
# Date
# 1998-01-01                       NaN                            NaN
# 1998-01-02                       NaN                            NaN
#
#             XLE US Equity_ratio1825zscore  XLK US Equity_ratio1825zscore  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             XLV US Equity_ratio1825zscore  XLI US Equity_ratio1825zscore  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             XLY US Equity_ratio1825zscore  XLB US Equity_ratio1825zscore  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             USURTOT Index365zscore  CPI YOY Index365zscore  \
# Date
# 1998-01-01                     NaN                     NaN
# 1998-01-02                     NaN                     NaN
#
#             AHE YOY% Index365zscore  OUTFGAF Index365zscore  \
# Date
# 1998-01-01                      NaN                     NaN
# 1998-01-02                      NaN                     NaN
#
#             CONSSENT Index365zscore  NHSPSTOT Index365zscore  \
# Date
# 1998-01-01                      NaN                      NaN
# 1998-01-02                      NaN                      NaN
#
#             CPTICHNG Index365zscore  LEI CHNG Index365zscore  \
# Date
# 1998-01-01                      NaN                      NaN
# 1998-01-02                      NaN                      NaN
#
#             SPE AUTO Index365zscore  NAPMNEWO Index365zscore  \
# Date
# 1998-01-01                      NaN                      NaN
# 1998-01-02                      NaN                      NaN
#
#             USURTOT Index1095zscore  CPI YOY Index1095zscore  \
# Date
# 1998-01-01                      NaN                      NaN
# 1998-01-02                      NaN                      NaN
#
#             AHE YOY% Index1095zscore  OUTFGAF Index1095zscore  \
# Date
# 1998-01-01                       NaN                      NaN
# 1998-01-02                       NaN                      NaN
#
#             CONSSENT Index1095zscore  NHSPSTOT Index1095zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             CPTICHNG Index1095zscore  LEI CHNG Index1095zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             SPE AUTO Index1095zscore  NAPMNEWO Index1095zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             USURTOT Index1825zscore  CPI YOY Index1825zscore  \
# Date
# 1998-01-01                      NaN                      NaN
# 1998-01-02                      NaN                      NaN
#
#             AHE YOY% Index1825zscore  OUTFGAF Index1825zscore  \
# Date
# 1998-01-01                       NaN                      NaN
# 1998-01-02                       NaN                      NaN
#
#             CONSSENT Index1825zscore  NHSPSTOT Index1825zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             CPTICHNG Index1825zscore  LEI CHNG Index1825zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             SPE AUTO Index1825zscore  NAPMNEWO Index1825zscore  \
# Date
# 1998-01-01                       NaN                       NaN
# 1998-01-02                       NaN                       NaN
#
#             USURTOT Index change in 30ds  CPI YOY Index change in 30ds  \
# Date
# 1998-01-01                           NaN                           NaN
# 1998-01-02                           NaN                           NaN
#
#             AHE YOY% Index change in 30ds  OUTFGAF Index change in 30ds  \
# Date
# 1998-01-01                            NaN                           NaN
# 1998-01-02                            NaN                           NaN
#
#             CONSSENT Index change in 30ds  NHSPSTOT Index change in 30ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             CPTICHNG Index change in 30ds  LEI CHNG Index change in 30ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             SPE AUTO Index change in 30ds  NAPMNEWO Index change in 30ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             FDTR Index change in 30ds  VIX Index change in 30ds  \
# Date
# 1998-01-01                        NaN                       NaN
# 1998-01-02                        NaN                       NaN
#
#             USGG5YR Index change in 30ds  USYC2Y10 Index change in 30ds  \
# Date
# 1998-01-01                           NaN                            NaN
# 1998-01-02                           NaN                            NaN
#
#             GFSIFFND Index change in 30ds  PCUSEQTR Index change in 30ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             US0003M Index change in 30ds  USGGBE05 Index change in 30ds  \
# Date
# 1998-01-01                           NaN                            NaN
# 1998-01-02                           NaN                            NaN
#
#             LF98OAS Index change in 30ds  XLF US Equity_ratio change in 30ds  \
# Date
# 1998-01-01                           NaN                                 NaN
# 1998-01-02                           NaN                                 NaN
#
#             XLE US Equity_ratio change in 30ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLK US Equity_ratio change in 30ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLV US Equity_ratio change in 30ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLI US Equity_ratio change in 30ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLY US Equity_ratio change in 30ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLB US Equity_ratio change in 30ds  USURTOT Index change in 90ds  \
# Date
# 1998-01-01                                 NaN                           NaN
# 1998-01-02                                 NaN                           NaN
#
#             CPI YOY Index change in 90ds  AHE YOY% Index change in 90ds  \
# Date
# 1998-01-01                           NaN                            NaN
# 1998-01-02                           NaN                            NaN
#
#             OUTFGAF Index change in 90ds  CONSSENT Index change in 90ds  \
# Date
# 1998-01-01                           NaN                            NaN
# 1998-01-02                           NaN                            NaN
#
#             NHSPSTOT Index change in 90ds  CPTICHNG Index change in 90ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             LEI CHNG Index change in 90ds  SPE AUTO Index change in 90ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             NAPMNEWO Index change in 90ds  FDTR Index change in 90ds  \
# Date
# 1998-01-01                            NaN                        NaN
# 1998-01-02                            NaN                        NaN
#
#             VIX Index change in 90ds  USGG5YR Index change in 90ds  \
# Date
# 1998-01-01                       NaN                           NaN
# 1998-01-02                       NaN                           NaN
#
#             USYC2Y10 Index change in 90ds  GFSIFFND Index change in 90ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             PCUSEQTR Index change in 90ds  US0003M Index change in 90ds  \
# Date
# 1998-01-01                            NaN                           NaN
# 1998-01-02                            NaN                           NaN
#
#             USGGBE05 Index change in 90ds  LF98OAS Index change in 90ds  \
# Date
# 1998-01-01                            NaN                           NaN
# 1998-01-02                            NaN                           NaN
#
#             XLF US Equity_ratio change in 90ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLE US Equity_ratio change in 90ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLK US Equity_ratio change in 90ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLV US Equity_ratio change in 90ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLI US Equity_ratio change in 90ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLY US Equity_ratio change in 90ds  \
# Date
# 1998-01-01                                 NaN
# 1998-01-02                                 NaN
#
#             XLB US Equity_ratio change in 90ds  USURTOT Index change in 365ds  \
# Date
# 1998-01-01                                 NaN                            NaN
# 1998-01-02                                 NaN                            NaN
#
#             CPI YOY Index change in 365ds  AHE YOY% Index change in 365ds  \
# Date
# 1998-01-01                            NaN                             NaN
# 1998-01-02                            NaN                             NaN
#
#             OUTFGAF Index change in 365ds  CONSSENT Index change in 365ds  \
# Date
# 1998-01-01                            NaN                             NaN
# 1998-01-02                            NaN                             NaN
#
#             NHSPSTOT Index change in 365ds  CPTICHNG Index change in 365ds  \
# Date
# 1998-01-01                             NaN                             NaN
# 1998-01-02                             NaN                             NaN
#
#             LEI CHNG Index change in 365ds  SPE AUTO Index change in 365ds  \
# Date
# 1998-01-01                             NaN                             NaN
# 1998-01-02                             NaN                             NaN
#
#             NAPMNEWO Index change in 365ds  FDTR Index change in 365ds  \
# Date
# 1998-01-01                             NaN                         NaN
# 1998-01-02                             NaN                         NaN
#
#             VIX Index change in 365ds  USGG5YR Index change in 365ds  \
# Date
# 1998-01-01                        NaN                            NaN
# 1998-01-02                        NaN                            NaN
#
#             USYC2Y10 Index change in 365ds  GFSIFFND Index change in 365ds  \
# Date
# 1998-01-01                             NaN                             NaN
# 1998-01-02                             NaN                             NaN
#
#             PCUSEQTR Index change in 365ds  US0003M Index change in 365ds  \
# Date
# 1998-01-01                             NaN                            NaN
# 1998-01-02                             NaN                            NaN
#
#             USGGBE05 Index change in 365ds  LF98OAS Index change in 365ds  \
# Date
# 1998-01-01                             NaN                            NaN
# 1998-01-02                             NaN                            NaN
#
#             XLF US Equity_ratio change in 365ds  \
# Date
# 1998-01-01                                  NaN
# 1998-01-02                                  NaN
#
#             XLE US Equity_ratio change in 365ds  \
# Date
# 1998-01-01                                  NaN
# 1998-01-02                                  NaN
#
#             XLK US Equity_ratio change in 365ds  \
# Date
# 1998-01-01                                  NaN
# 1998-01-02                                  NaN
#
#             XLV US Equity_ratio change in 365ds  \
# Date
# 1998-01-01                                  NaN
# 1998-01-02                                  NaN
#
#             XLI US Equity_ratio change in 365ds  \
# Date
# 1998-01-01                                  NaN
# 1998-01-02                                  NaN
#
#             XLY US Equity_ratio change in 365ds  \
# Date
# 1998-01-01                                  NaN
# 1998-01-02                                  NaN
#
#             XLB US Equity_ratio change in 365ds  \
# Date
# 1998-01-01                                  NaN
# 1998-01-02                                  NaN
#
#             USURTOT Index change in 1095ds  CPI YOY Index change in 1095ds  \
# Date
# 1998-01-01                             NaN                             NaN
# 1998-01-02                             NaN                             NaN
#
#             AHE YOY% Index change in 1095ds  OUTFGAF Index change in 1095ds  \
# Date
# 1998-01-01                              NaN                             NaN
# 1998-01-02                              NaN                             NaN
#
#             CONSSENT Index change in 1095ds  NHSPSTOT Index change in 1095ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             CPTICHNG Index change in 1095ds  LEI CHNG Index change in 1095ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             SPE AUTO Index change in 1095ds  NAPMNEWO Index change in 1095ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             FDTR Index change in 1095ds  VIX Index change in 1095ds  \
# Date
# 1998-01-01                          NaN                         NaN
# 1998-01-02                          NaN                         NaN
#
#             USGG5YR Index change in 1095ds  USYC2Y10 Index change in 1095ds  \
# Date
# 1998-01-01                             NaN                              NaN
# 1998-01-02                             NaN                              NaN
#
#             GFSIFFND Index change in 1095ds  PCUSEQTR Index change in 1095ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             US0003M Index change in 1095ds  USGGBE05 Index change in 1095ds  \
# Date
# 1998-01-01                             NaN                              NaN
# 1998-01-02                             NaN                              NaN
#
#             LF98OAS Index change in 1095ds  \
# Date
# 1998-01-01                             NaN
# 1998-01-02                             NaN
#
#             XLF US Equity_ratio change in 1095ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLE US Equity_ratio change in 1095ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLK US Equity_ratio change in 1095ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLV US Equity_ratio change in 1095ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLI US Equity_ratio change in 1095ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLY US Equity_ratio change in 1095ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLB US Equity_ratio change in 1095ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             USURTOT Index change in 1825ds  CPI YOY Index change in 1825ds  \
# Date
# 1998-01-01                             NaN                             NaN
# 1998-01-02                             NaN                             NaN
#
#             AHE YOY% Index change in 1825ds  OUTFGAF Index change in 1825ds  \
# Date
# 1998-01-01                              NaN                             NaN
# 1998-01-02                              NaN                             NaN
#
#             CONSSENT Index change in 1825ds  NHSPSTOT Index change in 1825ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             CPTICHNG Index change in 1825ds  LEI CHNG Index change in 1825ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             SPE AUTO Index change in 1825ds  NAPMNEWO Index change in 1825ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             FDTR Index change in 1825ds  VIX Index change in 1825ds  \
# Date
# 1998-01-01                          NaN                         NaN
# 1998-01-02                          NaN                         NaN
#
#             USGG5YR Index change in 1825ds  USYC2Y10 Index change in 1825ds  \
# Date
# 1998-01-01                             NaN                              NaN
# 1998-01-02                             NaN                              NaN
#
#             GFSIFFND Index change in 1825ds  PCUSEQTR Index change in 1825ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             US0003M Index change in 1825ds  USGGBE05 Index change in 1825ds  \
# Date
# 1998-01-01                             NaN                              NaN
# 1998-01-02                             NaN                              NaN
#
#             LF98OAS Index change in 1825ds  \
# Date
# 1998-01-01                             NaN
# 1998-01-02                             NaN
#
#             XLF US Equity_ratio change in 1825ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLE US Equity_ratio change in 1825ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLK US Equity_ratio change in 1825ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLV US Equity_ratio change in 1825ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLI US Equity_ratio change in 1825ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLY US Equity_ratio change in 1825ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             XLB US Equity_ratio change in 1825ds  \
# Date
# 1998-01-01                                   NaN
# 1998-01-02                                   NaN
#
#             CPI YOY Index %change in 30ds  CLA Comdty %change in 30ds  \
# Date
# 1998-01-01                            NaN                         NaN
# 1998-01-02                            NaN                         NaN
#
#             EMB US Equity %change in 30ds  SCGRRAI Index %change in 30ds  \
# Date
# 1998-01-01                            NaN                            NaN
# 1998-01-02                            NaN                            NaN
#
#             GFSIRLIQ Index %change in 30ds  CIGMGRAM Index %change in 30ds  \
# Date
# 1998-01-01                             NaN                             NaN
# 1998-01-02                             NaN                             NaN
#
#             SPX Index %change in 30ds  CPI YOY Index %change in 90ds  \
# Date
# 1998-01-01                        NaN                            NaN
# 1998-01-02                        NaN                            NaN
#
#             CLA Comdty %change in 90ds  EMB US Equity %change in 90ds  \
# Date
# 1998-01-01                         NaN                            NaN
# 1998-01-02                         NaN                            NaN
#
#             SCGRRAI Index %change in 90ds  GFSIRLIQ Index %change in 90ds  \
# Date
# 1998-01-01                            NaN                             NaN
# 1998-01-02                            NaN                             NaN
#
#             CIGMGRAM Index %change in 90ds  SPX Index %change in 90ds  \
# Date
# 1998-01-01                             NaN                        NaN
# 1998-01-02                             NaN                        NaN
#
#             CPI YOY Index %change in 365ds  CLA Comdty %change in 365ds  \
# Date
# 1998-01-01                             NaN                          NaN
# 1998-01-02                             NaN                          NaN
#
#             EMB US Equity %change in 365ds  SCGRRAI Index %change in 365ds  \
# Date
# 1998-01-01                             NaN                             NaN
# 1998-01-02                             NaN                             NaN
#
#             GFSIRLIQ Index %change in 365ds  CIGMGRAM Index %change in 365ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             SPX Index %change in 365ds  CPI YOY Index %change in 1095ds  \
# Date
# 1998-01-01                         NaN                              NaN
# 1998-01-02                         NaN                              NaN
#
#             CLA Comdty %change in 1095ds  EMB US Equity %change in 1095ds  \
# Date
# 1998-01-01                           NaN                              NaN
# 1998-01-02                           NaN                              NaN
#
#             SCGRRAI Index %change in 1095ds  GFSIRLIQ Index %change in 1095ds  \
# Date
# 1998-01-01                              NaN                               NaN
# 1998-01-02                              NaN                               NaN
#
#             CIGMGRAM Index %change in 1095ds  SPX Index %change in 1095ds  \
# Date
# 1998-01-01                               NaN                          NaN
# 1998-01-02                               NaN                          NaN
#
#             CPI YOY Index %change in 1825ds  CLA Comdty %change in 1825ds  \
# Date
# 1998-01-01                              NaN                           NaN
# 1998-01-02                              NaN                           NaN
#
#             EMB US Equity %change in 1825ds  SCGRRAI Index %change in 1825ds  \
# Date
# 1998-01-01                              NaN                              NaN
# 1998-01-02                              NaN                              NaN
#
#             GFSIRLIQ Index %change in 1825ds  \
# Date
# 1998-01-01                               NaN
# 1998-01-02                               NaN
#
#             CIGMGRAM Index %change in 1825ds  SPX Index %change in 1825ds
# Date
# 1998-01-01                               NaN                          NaN
# 1998-01-02                               NaN                          NaN

# %%
# Transform target variable into binary classification
# Shift target feature by xx days - predict signal xx days into the future

data['LF98OAS Index change in 30ds'] = data['LF98OAS Index change in 30ds'].shift(-5)

data['Signal'] = [1 if i >= abs(0.3) else 0 for i in data['LF98OAS Index change in 30ds']]
 
data['Signal'].value_counts()
# Out:
# 0    5776
# 1    1588
# Name: Signal, dtype: int64

# %% [markdown]
# **Plot the classes**

# %%
plt.hist(data['Signal'], bins=range(0,3), rwidth=0.8, color='cadetblue')

plt.xlabel(('No jump event vs. jump event'))
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %% [markdown]
# *This is an imbalanced dataset - resampling is required.*

# %% [markdown]
# **Define input and target variables**

# %%
# target

y = data['Signal'].fillna(0)

# remove features relating to target from dataset

X_prel = data.drop(['LF98OAS Index', 'LF98OAS Index change in 30ds','LF98OAS Index change in 90ds',\
          'LF98OAS Index change in 365ds', 'LF98OAS Index change in 1095ds',\
          'LF98OAS Index change in 1825ds', 'Signal'], axis=1)

# %%
#check if X contains any column related to target variable

cols = list(X_prel.columns)

for col in cols:
    if "LF98OAS" in col:
        print (col)

# %% [markdown]
# **Calculate class weights**

# %%
naive = data['Signal'].value_counts()# naive prediction
print(naive)
# Out:
# 0    5776
# 1    1588
# Name: Signal, dtype: int64

# %%
def weight(cl):
    if cl==1:
        return naive[0].astype(float)/naive[1].astype(float)
    else:
        return 1

wgt = y.apply(weight)

# %%
wgt.value_counts()
# Out:
# 1.00000    5776
# 3.63728    1588
# Name: Signal, dtype: int64

# %%
#address inf and nan values
X_tidy = X_prel.replace([np.inf, -np.inf], np.nan).fillna(0)

# %%
# remove remaining original indices

remaining = ['FDTR Index', 'VIX Index', 'USGG5YR Index', 'USYC2Y10 Index',
       'CPI YOY Index', 'USURTOT Index', 'OUTFGAF Index', 'CLA Comdty',
       'CONSSENT Index', 'SCGRRAI Index', 'EMB US Equity', 'SPE AUTO Index',
       'SPE CARD Index', 'LEI CHNG Index', 'GFSIFFND Index', 
       'PCUSEQTR Index', 'GFSIRLIQ Index', 'CIGMGRAM Index', 'SPX Index', 
        'US0003M Index', 'AHE YOY% Index', 'NHSPSTOT Index', 'NAPMNEWO Index',
        'CPTICHNG Index', 'USGGBE05 Index', 'XLF US Equity_ratio', 'XLE US Equity_ratio',
             'XLK US Equity_ratio', 'XLV US Equity_ratio', 'XLI US Equity_ratio',
             'XLY US Equity_ratio', 'XLB US Equity_ratio']

X = X_tidy.drop(X_tidy[remaining], axis=1)

# %%
#split out training and testing sets

X_train = X[:5301]
y_train = y[:5301]
X_test = X[5301:]
y_test = y[5301:]
y_test.value_counts()
# Out:
# 0    1712
# 1     351
# Name: Signal, dtype: int64

# %%
X_test.head(1)
# Out:
#             CLA Comdty30zscore  SCGRRAI Index30zscore  EMB US Equity30zscore  \
# Date
# 2012-07-07                 0.0               1.246809               1.622422
#
#             GFSIRLIQ Index30zscore  CIGMGRAM Index30zscore  \
# Date
# 2012-07-07                 -2.2273               -0.573663
#
#             FDTR Index30zscore  VIX Index30zscore  USGG5YR Index30zscore  \
# Date
# 2012-07-07                 0.0          -1.014299              -1.990553
#
#             USYC2Y10 Index30zscore  GFSIFFND Index30zscore  \
# Date
# 2012-07-07               -1.578666               -2.368161
#
#             PCUSEQTR Index30zscore  SPX Index30zscore  US0003M Index30zscore  \
# Date
# 2012-07-07                 0.51021           0.701585              -1.583545
#
#             USGGBE05 Index30zscore  XLF US Equity_ratio30zscore  \
# Date
# 2012-07-07               -0.098069                    -0.401387
#
#             XLE US Equity_ratio30zscore  XLK US Equity_ratio30zscore  \
# Date
# 2012-07-07                      0.76776                     -0.47815
#
#             XLV US Equity_ratio30zscore  XLI US Equity_ratio30zscore  \
# Date
# 2012-07-07                    -0.250315                    -0.758318
#
#             XLY US Equity_ratio30zscore  XLB US Equity_ratio30zscore  \
# Date
# 2012-07-07                     -0.36584                      0.62777
#
#             CLA Comdty90zscore  SCGRRAI Index90zscore  EMB US Equity90zscore  \
# Date
# 2012-07-07                 0.0               2.209975               1.616089
#
#             GFSIRLIQ Index90zscore  CIGMGRAM Index90zscore  \
# Date
# 2012-07-07               -2.549161               -0.236041
#
#             FDTR Index90zscore  VIX Index90zscore  USGG5YR Index90zscore  \
# Date
# 2012-07-07                 0.0          -1.086737               -1.65067
#
#             USYC2Y10 Index90zscore  GFSIFFND Index90zscore  \
# Date
# 2012-07-07               -1.206839               -0.362411
#
#             PCUSEQTR Index90zscore  SPX Index90zscore  US0003M Index90zscore  \
# Date
# 2012-07-07                0.433164           0.251122               -2.98916
#
#             USGGBE05 Index90zscore  XLF US Equity_ratio90zscore  \
# Date
# 2012-07-07               -0.764835                    -0.698616
#
#             XLE US Equity_ratio90zscore  XLK US Equity_ratio90zscore  \
# Date
# 2012-07-07                    -0.452986                    -0.783225
#
#             XLV US Equity_ratio90zscore  XLI US Equity_ratio90zscore  \
# Date
# 2012-07-07                     0.761692                    -1.513573
#
#             XLY US Equity_ratio90zscore  XLB US Equity_ratio90zscore  \
# Date
# 2012-07-07                    -0.890595                    -0.028646
#
#             CLA Comdty365zscore  SCGRRAI Index365zscore  \
# Date
# 2012-07-07                  0.0                1.462016
#
#             EMB US Equity365zscore  GFSIRLIQ Index365zscore  \
# Date
# 2012-07-07                2.068476                -1.473982
#
#             CIGMGRAM Index365zscore  FDTR Index365zscore  VIX Index365zscore  \
# Date
# 2012-07-07                -0.810352                  0.0           -0.968897
#
#             USGG5YR Index365zscore  USYC2Y10 Index365zscore  \
# Date
# 2012-07-07               -1.450734                -1.710586
#
#             GFSIFFND Index365zscore  PCUSEQTR Index365zscore  \
# Date
# 2012-07-07                -0.139486                 0.569098
#
#             SPX Index365zscore  US0003M Index365zscore  \
# Date
# 2012-07-07            0.840052                0.151652
#
#             USGGBE05 Index365zscore  XLF US Equity_ratio365zscore  \
# Date
# 2012-07-07                -0.112973                     -0.225237
#
#             XLE US Equity_ratio365zscore  XLK US Equity_ratio365zscore  \
# Date
# 2012-07-07                     -1.552952                      0.749023
#
#             XLV US Equity_ratio365zscore  XLI US Equity_ratio365zscore  \
# Date
# 2012-07-07                      1.334396                     -1.362403
#
#             XLY US Equity_ratio365zscore  XLB US Equity_ratio365zscore  \
# Date
# 2012-07-07                      1.098919                     -1.116955
#
#             CLA Comdty1095zscore  SCGRRAI Index1095zscore  \
# Date
# 2012-07-07                   0.0                 1.255479
#
#             EMB US Equity1095zscore  GFSIRLIQ Index1095zscore  \
# Date
# 2012-07-07                 1.914772                 -0.628875
#
#             CIGMGRAM Index1095zscore  FDTR Index1095zscore  \
# Date
# 2012-07-07                  0.052827                   0.0
#
#             VIX Index1095zscore  USGG5YR Index1095zscore  \
# Date
# 2012-07-07            -0.917309                -1.605191
#
#             USYC2Y10 Index1095zscore  GFSIFFND Index1095zscore  \
# Date
# 2012-07-07                 -2.280756                  0.490412
#
#             PCUSEQTR Index1095zscore  SPX Index1095zscore  \
# Date
# 2012-07-07                  1.028956             1.301406
#
#             US0003M Index1095zscore  USGGBE05 Index1095zscore  \
# Date
# 2012-07-07                 0.886264                  0.150008
#
#             XLF US Equity_ratio1095zscore  XLE US Equity_ratio1095zscore  \
# Date
# 2012-07-07                      -1.302825                      -1.195122
#
#             XLK US Equity_ratio1095zscore  XLV US Equity_ratio1095zscore  \
# Date
# 2012-07-07                       1.730611                       0.894103
#
#             XLI US Equity_ratio1095zscore  XLY US Equity_ratio1095zscore  \
# Date
# 2012-07-07                      -0.644787                       1.423914
#
#             XLB US Equity_ratio1095zscore  CLA Comdty1825zscore  \
# Date
# 2012-07-07                      -2.043013                   0.0
#
#             SCGRRAI Index1825zscore  EMB US Equity1825zscore  \
# Date
# 2012-07-07                 1.179423                 0.742209
#
#             GFSIRLIQ Index1825zscore  CIGMGRAM Index1825zscore  \
# Date
# 2012-07-07                  -0.62423                  -0.25717
#
#             FDTR Index1825zscore  VIX Index1825zscore  \
# Date
# 2012-07-07             -0.544251            -0.851814
#
#             USGG5YR Index1825zscore  USYC2Y10 Index1825zscore  \
# Date
# 2012-07-07                -1.576841                 -1.071367
#
#             GFSIFFND Index1825zscore  PCUSEQTR Index1825zscore  \
# Date
# 2012-07-07                  0.131485                  0.614192
#
#             SPX Index1825zscore  US0003M Index1825zscore  \
# Date
# 2012-07-07             0.817603                -0.587486
#
#             USGGBE05 Index1825zscore  XLF US Equity_ratio1825zscore  \
# Date
# 2012-07-07                   0.23066                      -0.983615
#
#             XLE US Equity_ratio1825zscore  XLK US Equity_ratio1825zscore  \
# Date
# 2012-07-07                      -1.145927                       1.433137
#
#             XLV US Equity_ratio1825zscore  XLI US Equity_ratio1825zscore  \
# Date
# 2012-07-07                       0.614998                        -0.4055
#
#             XLY US Equity_ratio1825zscore  XLB US Equity_ratio1825zscore  \
# Date
# 2012-07-07                       1.585699                      -1.615643
#
#             USURTOT Index365zscore  CPI YOY Index365zscore  \
# Date
# 2012-07-07               -1.139322               -2.290926
#
#             AHE YOY% Index365zscore  OUTFGAF Index365zscore  \
# Date
# 2012-07-07                -1.614573               -0.313276
#
#             CONSSENT Index365zscore  NHSPSTOT Index365zscore  \
# Date
# 2012-07-07                 1.413429                  0.71815
#
#             CPTICHNG Index365zscore  LEI CHNG Index365zscore  \
# Date
# 2012-07-07                 1.116659                -0.161979
#
#             SPE AUTO Index365zscore  NAPMNEWO Index365zscore  \
# Date
# 2012-07-07                -2.405711                 1.061098
#
#             USURTOT Index1095zscore  CPI YOY Index1095zscore  \
# Date
# 2012-07-07                -1.853485                -0.117882
#
#             AHE YOY% Index1095zscore  OUTFGAF Index1095zscore  \
# Date
# 2012-07-07                 -1.156665                -0.935557
#
#             CONSSENT Index1095zscore  NHSPSTOT Index1095zscore  \
# Date
# 2012-07-07                  1.710502                  1.611305
#
#             CPTICHNG Index1095zscore  LEI CHNG Index1095zscore  \
# Date
# 2012-07-07                   1.06324                 -0.745033
#
#             SPE AUTO Index1095zscore  NAPMNEWO Index1095zscore  \
# Date
# 2012-07-07                 -1.437522                 -0.153233
#
#             USURTOT Index1825zscore  CPI YOY Index1825zscore  \
# Date
# 2012-07-07                 0.124451                -0.291918
#
#             AHE YOY% Index1825zscore  OUTFGAF Index1825zscore  \
# Date
# 2012-07-07                 -1.244758                -0.009801
#
#             CONSSENT Index1825zscore  NHSPSTOT Index1825zscore  \
# Date
# 2012-07-07                  1.209884                 -0.126437
#
#             CPTICHNG Index1825zscore  LEI CHNG Index1825zscore  \
# Date
# 2012-07-07                  0.551538                  0.283872
#
#             SPE AUTO Index1825zscore  NAPMNEWO Index1825zscore  \
# Date
# 2012-07-07                 -1.792877                  0.437818
#
#             USURTOT Index change in 30ds  CPI YOY Index change in 30ds  \
# Date
# 2012-07-07                           0.0                          -0.6
#
#             AHE YOY% Index change in 30ds  OUTFGAF Index change in 30ds  \
# Date
# 2012-07-07                           -0.4                          -6.4
#
#             CONSSENT Index change in 30ds  NHSPSTOT Index change in 30ds  \
# Date
# 2012-07-07                            2.9                          -45.0
#
#             CPTICHNG Index change in 30ds  LEI CHNG Index change in 30ds  \
# Date
# 2012-07-07                        -0.0039                            0.3
#
#             SPE AUTO Index change in 30ds  NAPMNEWO Index change in 30ds  \
# Date
# 2012-07-07                          -0.04                            0.0
#
#             FDTR Index change in 30ds  VIX Index change in 30ds  \
# Date
# 2012-07-07                        0.0                     -4.62
#
#             USGG5YR Index change in 30ds  USYC2Y10 Index change in 30ds  \
# Date
# 2012-07-07                       -0.0669                         -9.365
#
#             GFSIFFND Index change in 30ds  PCUSEQTR Index change in 30ds  \
# Date
# 2012-07-07                          -0.28                           0.11
#
#             US0003M Index change in 30ds  USGGBE05 Index change in 30ds  \
# Date
# 2012-07-07                      -0.01025                         0.0075
#
#             XLF US Equity_ratio change in 30ds  \
# Date
# 2012-07-07                            0.000047
#
#             XLE US Equity_ratio change in 30ds  \
# Date
# 2012-07-07                           -0.000108
#
#             XLK US Equity_ratio change in 30ds  \
# Date
# 2012-07-07                            -0.00013
#
#             XLV US Equity_ratio change in 30ds  \
# Date
# 2012-07-07                             0.00012
#
#             XLI US Equity_ratio change in 30ds  \
# Date
# 2012-07-07                           -0.000275
#
#             XLY US Equity_ratio change in 30ds  \
# Date
# 2012-07-07                           -0.000412
#
#             XLB US Equity_ratio change in 30ds  USURTOT Index change in 90ds  \
# Date
# 2012-07-07                           -0.000175                           0.0
#
#             CPI YOY Index change in 90ds  AHE YOY% Index change in 90ds  \
# Date
# 2012-07-07                          -1.2                           -0.1
#
#             OUTFGAF Index change in 90ds  CONSSENT Index change in 90ds  \
# Date
# 2012-07-07                         -10.8                            4.0
#
#             NHSPSTOT Index change in 90ds  CPTICHNG Index change in 90ds  \
# Date
# 2012-07-07                            4.0                        -0.0937
#
#             LEI CHNG Index change in 90ds  SPE AUTO Index change in 90ds  \
# Date
# 2012-07-07                           -0.5                          -0.19
#
#             NAPMNEWO Index change in 90ds  FDTR Index change in 90ds  \
# Date
# 2012-07-07                           -0.2                        0.0
#
#             VIX Index change in 90ds  USGG5YR Index change in 90ds  \
# Date
# 2012-07-07                       0.4                       -0.2541
#
#             USYC2Y10 Index change in 90ds  GFSIFFND Index change in 90ds  \
# Date
# 2012-07-07                        -46.061                           0.23
#
#             PCUSEQTR Index change in 90ds  US0003M Index change in 90ds  \
# Date
# 2012-07-07                           0.15                      -0.01155
#
#             USGGBE05 Index change in 90ds  XLF US Equity_ratio change in 90ds  \
# Date
# 2012-07-07                        -0.1699                           -0.000349
#
#             XLE US Equity_ratio change in 90ds  \
# Date
# 2012-07-07                           -0.001492
#
#             XLK US Equity_ratio change in 90ds  \
# Date
# 2012-07-07                           -0.000401
#
#             XLV US Equity_ratio change in 90ds  \
# Date
# 2012-07-07                            0.000948
#
#             XLI US Equity_ratio change in 90ds  \
# Date
# 2012-07-07                           -0.000452
#
#             XLY US Equity_ratio change in 90ds  \
# Date
# 2012-07-07                            0.000116
#
#             XLB US Equity_ratio change in 90ds  USURTOT Index change in 365ds  \
# Date
# 2012-07-07                           -0.000146                           -0.9
#
#             CPI YOY Index change in 365ds  AHE YOY% Index change in 365ds  \
# Date
# 2012-07-07                           -1.9                            -0.3
#
#             OUTFGAF Index change in 365ds  CONSSENT Index change in 365ds  \
# Date
# 2012-07-07                           -6.9                             5.0
#
#             NHSPSTOT Index change in 365ds  CPTICHNG Index change in 365ds  \
# Date
# 2012-07-07                           147.0                          1.4731
#
#             LEI CHNG Index change in 365ds  SPE AUTO Index change in 365ds  \
# Date
# 2012-07-07                            -0.5                           -0.31
#
#             NAPMNEWO Index change in 365ds  FDTR Index change in 365ds  \
# Date
# 2012-07-07                             2.6                         0.0
#
#             VIX Index change in 365ds  USGG5YR Index change in 365ds  \
# Date
# 2012-07-07                       1.15                        -0.9342
#
#             USYC2Y10 Index change in 365ds  GFSIFFND Index change in 365ds  \
# Date
# 2012-07-07                        -135.667                            -0.2
#
#             PCUSEQTR Index change in 365ds  US0003M Index change in 365ds  \
# Date
# 2012-07-07                            0.17                        0.21155
#
#             USGGBE05 Index change in 365ds  \
# Date
# 2012-07-07                         -0.2461
#
#             XLF US Equity_ratio change in 365ds  \
# Date
# 2012-07-07                            -0.000668
#
#             XLE US Equity_ratio change in 365ds  \
# Date
# 2012-07-07                            -0.008284
#
#             XLK US Equity_ratio change in 365ds  \
# Date
# 2012-07-07                             0.001481
#
#             XLV US Equity_ratio change in 365ds  \
# Date
# 2012-07-07                             0.001152
#
#             XLI US Equity_ratio change in 365ds  \
# Date
# 2012-07-07                            -0.002153
#
#             XLY US Equity_ratio change in 365ds  \
# Date
# 2012-07-07                             0.001524
#
#             XLB US Equity_ratio change in 365ds  \
# Date
# 2012-07-07                             -0.00399
#
#             USURTOT Index change in 1095ds  CPI YOY Index change in 1095ds  \
# Date
# 2012-07-07                            -1.3                             3.0
#
#             AHE YOY% Index change in 1095ds  OUTFGAF Index change in 1095ds  \
# Date
# 2012-07-07                             -1.2                            21.6
#
#             CONSSENT Index change in 1095ds  NHSPSTOT Index change in 1095ds  \
# Date
# 2012-07-07                             10.6                            168.0
#
#             CPTICHNG Index change in 1095ds  LEI CHNG Index change in 1095ds  \
# Date
# 2012-07-07                          10.4338                             -0.3
#
#             SPE AUTO Index change in 1095ds  NAPMNEWO Index change in 1095ds  \
# Date
# 2012-07-07                            -1.08                              6.2
#
#             FDTR Index change in 1095ds  VIX Index change in 1095ds  \
# Date
# 2012-07-07                          0.0                       -14.2
#
#             USGG5YR Index change in 1095ds  USYC2Y10 Index change in 1095ds  \
# Date
# 2012-07-07                         -1.5885                         -111.886
#
#             GFSIFFND Index change in 1095ds  PCUSEQTR Index change in 1095ds  \
# Date
# 2012-07-07                             0.84                            -0.11
#
#             US0003M Index change in 1095ds  USGGBE05 Index change in 1095ds  \
# Date
# 2012-07-07                         -0.0674                           0.6743
#
#             XLF US Equity_ratio change in 1095ds  \
# Date
# 2012-07-07                             -0.001583
#
#             XLE US Equity_ratio change in 1095ds  \
# Date
# 2012-07-07                             -0.001694
#
#             XLK US Equity_ratio change in 1095ds  \
# Date
# 2012-07-07                              0.001453
#
#             XLV US Equity_ratio change in 1095ds  \
# Date
# 2012-07-07                             -0.001885
#
#             XLI US Equity_ratio change in 1095ds  \
# Date
# 2012-07-07                              0.002616
#
#             XLY US Equity_ratio change in 1095ds  \
# Date
# 2012-07-07                              0.007319
#
#             XLB US Equity_ratio change in 1095ds  \
# Date
# 2012-07-07                             -0.001635
#
#             USURTOT Index change in 1825ds  CPI YOY Index change in 1825ds  \
# Date
# 2012-07-07                             3.6                            -1.0
#
#             AHE YOY% Index change in 1825ds  OUTFGAF Index change in 1825ds  \
# Date
# 2012-07-07                             -1.8                            -4.5
#
#             CONSSENT Index change in 1825ds  NHSPSTOT Index change in 1825ds  \
# Date
# 2012-07-07                             -9.0                           -707.0
#
#             CPTICHNG Index change in 1825ds  LEI CHNG Index change in 1825ds  \
# Date
# 2012-07-07                          -3.4334                              0.0
#
#             SPE AUTO Index change in 1825ds  NAPMNEWO Index change in 1825ds  \
# Date
# 2012-07-07                            -0.37                              0.2
#
#             FDTR Index change in 1825ds  VIX Index change in 1825ds  \
# Date
# 2012-07-07                         -5.0                        1.94
#
#             USGG5YR Index change in 1825ds  USYC2Y10 Index change in 1825ds  \
# Date
# 2012-07-07                         -4.4006                          108.476
#
#             GFSIFFND Index change in 1825ds  PCUSEQTR Index change in 1825ds  \
# Date
# 2012-07-07                             -0.2                             0.23
#
#             US0003M Index change in 1825ds  USGGBE05 Index change in 1825ds  \
# Date
# 2012-07-07                         -4.9024                          -0.5258
#
#             XLF US Equity_ratio change in 1825ds  \
# Date
# 2012-07-07                             -0.010691
#
#             XLE US Equity_ratio change in 1825ds  \
# Date
# 2012-07-07                              0.001795
#
#             XLK US Equity_ratio change in 1825ds  \
# Date
# 2012-07-07                               0.00401
#
#             XLV US Equity_ratio change in 1825ds  \
# Date
# 2012-07-07                              0.004584
#
#             XLI US Equity_ratio change in 1825ds  \
# Date
# 2012-07-07                             -0.000186
#
#             XLY US Equity_ratio change in 1825ds  \
# Date
# 2012-07-07                              0.006185
#
#             XLB US Equity_ratio change in 1825ds  \
# Date
# 2012-07-07                             -0.001275
#
#             CPI YOY Index %change in 30ds  CLA Comdty %change in 30ds  \
# Date
# 2012-07-07                       -0.26087                         0.0
#
#             EMB US Equity %change in 30ds  SCGRRAI Index %change in 30ds  \
# Date
# 2012-07-07                       0.034273                      -2.399808
#
#             GFSIRLIQ Index %change in 30ds  CIGMGRAM Index %change in 30ds  \
# Date
# 2012-07-07                       -0.232558                       -0.197711
#
#             SPX Index %change in 30ds  CPI YOY Index %change in 90ds  \
# Date
# 2012-07-07                   0.030183                      -0.413793
#
#             CLA Comdty %change in 90ds  EMB US Equity %change in 90ds  \
# Date
# 2012-07-07                         0.0                       0.030676
#
#             SCGRRAI Index %change in 90ds  GFSIRLIQ Index %change in 90ds  \
# Date
# 2012-07-07                      -2.060545                       -0.232558
#
#             CIGMGRAM Index %change in 90ds  SPX Index %change in 90ds  \
# Date
# 2012-07-07                        0.259804                  -0.031043
#
#             CPI YOY Index %change in 365ds  CLA Comdty %change in 365ds  \
# Date
# 2012-07-07                       -0.527778                          0.0
#
#             EMB US Equity %change in 365ds  SCGRRAI Index %change in 365ds  \
# Date
# 2012-07-07                         0.05649                       -2.750075
#
#             GFSIRLIQ Index %change in 365ds  CIGMGRAM Index %change in 365ds  \
# Date
# 2012-07-07                           -0.175                         0.409506
#
#             SPX Index %change in 365ds  CPI YOY Index %change in 1095ds  \
# Date
# 2012-07-07                    0.008096                        -2.307692
#
#             CLA Comdty %change in 1095ds  EMB US Equity %change in 1095ds  \
# Date
# 2012-07-07                           0.0                          0.24628
#
#             SCGRRAI Index %change in 1095ds  GFSIRLIQ Index %change in 1095ds  \
# Date
# 2012-07-07                        -2.029292                           -0.5875
#
#             CIGMGRAM Index %change in 1095ds  SPX Index %change in 1095ds  \
# Date
# 2012-07-07                         -0.319506                     0.540179
#
#             CPI YOY Index %change in 1825ds  CLA Comdty %change in 1825ds  \
# Date
# 2012-07-07                         -0.37037                           0.0
#
#             EMB US Equity %change in 1825ds  SCGRRAI Index %change in 1825ds  \
# Date
# 2012-07-07                              0.0                         2.182215
#
#             GFSIRLIQ Index %change in 1825ds  \
# Date
# 2012-07-07                         -2.434783
#
#             CIGMGRAM Index %change in 1825ds  SPX Index %change in 1825ds
# Date
# 2012-07-07                         -1.850993                    -0.115658

# %% [markdown]
# **Gradient Boosted Trees**

# %%
#try Gradient Boosted Trees

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import log_loss
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import TimeSeriesSplit

# tuning the number of leaves
group = []
for i in np.linspace(10,20,num=11):
    i=int(i)
    params = {'n_estimators': 500, 'max_depth': 10, 'max_features': 0.4,
          'learning_rate': 0.01, 'max_leaf_nodes': i, 'random_state': 47}

    gbc = GradientBoostingClassifier(**params)

    gbc.fit(X_train, y_train,sample_weight=wgt[:5301])
    
    tscv = TimeSeriesSplit(n_splits=3)
    
    scores = cross_val_score(gbc, X_train, y_train, cv=tscv, scoring='neg_log_loss')
    group.append((i, log_loss(y_test, gbc.predict_proba(X_test)[:,1]),
                  log_loss(y_train, gbc.predict_proba(X_train)[:,1]),
                  scores.mean(), scores.std()))

# %% [markdown]
# The actual log loss is simply the positive version of the negative log loss number.
#
# SK-Learn's unified scoring API always maximizes the score, so scores which need to be minimized are negated in order for the unified scoring API to work correctly. The score that is returned is therefore negated when it is a score that should be minimized and left positive if it is a score that should be maximized.

# %%
print(group)
# Out:
# [(10, 0.35481523708501439, 0.15416271863205752, -0.62038797719856242, 0.30050826058476177), (11, 0.35653408862643937, 0.14430895535377689, -0.57661831177472767, 0.23254905610720078), (12, 0.36216231955455086, 0.13423767289895364, -0.55158472357270261, 0.21414518784202557), (13, 0.35831230928756114, 0.12559807841613294, -0.5360032608948907, 0.17639331499706354), (14, 0.35812195801365798, 0.11850198116154313, -0.52836074105482089, 0.16118873787132065), (15, 0.3615593584489904, 0.11195545625852477, -0.52842034892859535, 0.16217066126380517), (16, 0.36551715392054457, 0.10565126435568835, -0.52802017951469704, 0.15988847694117561), (17, 0.37220983919854, 0.10003397138726371, -0.53151981560008699, 0.15850315371639989), (18, 0.36088752653298273, 0.094767693948142578, -0.53327138436103239, 0.15388070052152156), (19, 0.36456115686749535, 0.089740870787860458, -0.53718735642514581, 0.1640179907478197), (20, 0.36743298459815582, 0.085685737854936966, -0.55146512893241295, 0.18053951407346552)]

# %% [markdown]
# **Plotting model performance**

# %%
sns.set_style("whitegrid")

group_results = pd.DataFrame(data=group)
group_results.columns = ['Max_leaf_nodes','Test logloss','Train logloss',
                         'Average cross validation logloss','Std cross validation']
group_results = group_results.set_index('Max_leaf_nodes')
group_results['Average cross validation logloss'] = group_results['Average cross validation logloss'] * -1
group_results.plot()
plt.legend(loc = 'best')

# %%
sns.set_style("white")

feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(X_test.columns, gbc.feature_importances_):
    feats[feature] = importance #add the name/value pair 

importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Importance'})
importances = importances[:20]
importances.sort_values(by='Importance', ascending=False).plot(kind='bar', rot=90, color=color)
plt.legend(loc = 'best')

# %%
y_pred = gbc.predict_proba(X_test)
y_pred = pd.DataFrame(y_pred, index = y_test.index)
y_pred_train = gbc.predict_proba(X_train)
y_pred_train = pd.DataFrame(y_pred_train, index = y_train.index)

# how does the model perform on once reduced dataset?

Logloss = log_loss(y_test, y_pred[1])
Logloss_train = log_loss(y_train, y_pred_train[1])
print("The logloss score on the testing set for the model is {:.4f}.".format(Logloss))
print("The logloss score on the training set for the model is {:.4f}.".format(Logloss_train))
# Out:
# The logloss score on the testing set for the model is 0.3674.
# The logloss score on the training set for the model is 0.0857.

# %%
import math
test_prob_BM = math.exp(-Logloss)
train_prob_BM = math.exp(-Logloss_train)
print(test_prob_BM, train_prob_BM)
# Out:
# (0.6925097340717352, 0.917882641667421)

# %% [markdown]
# **Feature elimination with cross-validation**

# %%
# try RFE with cross-validation

from sklearn.feature_selection import RFECV

rfecv = RFECV(estimator=gbc, scoring='neg_log_loss', step=1)
rfecv.fit(X_train, y_train)

print("Optimal number of features : %d" % rfecv.n_features_)
# Out:
# Optimal number of features : 9

# %%
feats2 = pd.DataFrame(rfecv.support_).transpose()
feats2.columns = X_test.columns
feats2 = feats2.transpose()
feats2.columns = ['True or False']
feats_new = feats2[feats2['True or False']==True]
feats_new_T = feats_new.transpose()

# %%
y_pred_rfecv = rfecv.predict_proba(X_test)
y_pred_rfecv = pd.DataFrame(y_pred_rfecv, index = y_test.index)
y_pred_train_rfecv = rfecv.predict_proba(X_train)
y_pred_train_rfecv = pd.DataFrame(y_pred_train_rfecv, index = y_train.index)

# how does the model perform on once reduced dataset?

Logloss_RFECV = log_loss(y_test, y_pred_rfecv[1])
Logloss__RFECV_train = log_loss(y_train, y_pred_train_rfecv[1])
print("The logloss score on the testing set for an optimised model is {:.4f}.".format(Logloss_RFECV))
print("The logloss score on the training set for the optimised model is {:.4f}.".format(Logloss__RFECV_train))
# Out:
# The logloss score on the testing set for an optimised model is 0.4187.
# The logloss score on the training set for the optimised model is 0.1078.

# %%
test_prob_BM = math.exp(-Logloss_RFECV)
train_prob_BM = math.exp(-Logloss__RFECV_train)
print(test_prob_BM, train_prob_BM)
# Out:
# (0.6579170863567618, 0.8978449810719659)

# %%
cols_rfe = feats_new_T.columns

X_rfe = X[cols_rfe]
X_train_rfe = X_rfe[:5301]
y_train = y[:5301]
X_test_rfe = X_rfe[5301:]
y_test = y[5301:]

X_rfe.head(2)
# Out:
#             GFSIFFND Index90zscore  US0003M Index365zscore  \
# Date
# 1998-01-01                     0.0                     0.0
# 1998-01-02                     0.0                     0.0
#
#             XLF US Equity_ratio1095zscore  LEI CHNG Index365zscore  \
# Date
# 1998-01-01                            0.0                      0.0
# 1998-01-02                            0.0                      0.0
#
#             NAPMNEWO Index365zscore  OUTFGAF Index1095zscore  \
# Date
# 1998-01-01                      0.0                      0.0
# 1998-01-02                      0.0                      0.0
#
#             NAPMNEWO Index change in 90ds  VIX Index change in 90ds  \
# Date
# 1998-01-01                            0.0                       0.0
# 1998-01-02                            0.0                       0.0
#
#             SPX Index %change in 30ds
# Date
# 1998-01-01                        0.0
# 1998-01-02                        0.0

# %% [markdown]
# **Addressing collinearity**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor    

def calculate_vif_(X, thresh=5.0):
    variables = list(range(X.shape[1])) # in Python3 use list(range(X.shape[1]))
    dropped=True
    while dropped:
        dropped=False
        vif = [variance_inflation_factor(X[variables].values, ix) for ix in range(X[variables].shape[1])]

        maxloc = vif.index(max(vif))
        if max(vif) > thresh:
            print('dropping \'' + X[variables].columns[maxloc] + '\' at index: ' + str(maxloc))
            del variables[maxloc]
            dropped=True

    print('Remaining variables:')
    print(X.columns[variables])
    return X[variables]

# %%
X_vif = calculate_vif_(X_rfe)
# Out:
# Remaining variables:
# Index([u'GFSIFFND Index90zscore', u'US0003M Index365zscore',
#        u'XLF US Equity_ratio1095zscore', u'LEI CHNG Index365zscore',
#        u'NAPMNEWO Index365zscore', u'OUTFGAF Index1095zscore',
#        u'NAPMNEWO Index change in 90ds', u'VIX Index change in 90ds',
#        u'SPX Index %change in 30ds'],
#       dtype='object')

# %%
X_train_vif = X_vif[:5301]
y_train = y[:5301]
X_test_vif = X_vif[5301:]
y_test = y[5301:]

# %%
# train model on reduced dataset

group2 = []
for i in np.linspace(10,20,num=11):
    i=int(i)
    params = {'n_estimators': 500, 'max_depth': 10, 'max_features': 9,
          'learning_rate': 0.01, 'max_leaf_nodes': i, 'random_state': 47}

    gbc2 = GradientBoostingClassifier(**params)

    gbc2.fit(X_train_vif, y_train,sample_weight=wgt[:5301])

    tscv = TimeSeriesSplit(n_splits=3)
    
    scores2 = cross_val_score(gbc2, X_train_vif, y_train, cv=tscv, scoring='neg_log_loss')
    group2.append((i, log_loss(y_test, gbc2.predict_proba(X_test_vif)[:,1]),
                  log_loss(y_train, gbc2.predict_proba(X_train_vif)[:,1]),
                  scores2.mean(), scores2.std()))

# %%
y_pred_vif = gbc2.predict_proba(X_test_vif)
y_pred_vif = pd.DataFrame(y_pred_vif, index = y_test.index)

y_pred_train_vif = gbc2.predict_proba(X_train_vif)
y_pred_train_vif = pd.DataFrame(y_pred_train_vif, index = y_train.index)

# how does the model perform on once reduced dataset?

Logloss_vif = log_loss(y_test, y_pred_vif[1])
Logloss_train_vif = log_loss(y_train, y_pred_train_vif[1])
print("The logloss score on the testing set after addressing collinearity is {:.4f}.".format(Logloss_vif))
print("The logloss score on the training set after addressing collinearity is {:.4f}.".format(Logloss_train_vif))
# Out:
# The logloss score on the testing set after addressing collinearity is 0.4049.
# The logloss score on the training set after addressing collinearity is 0.1255.

# %%
# transform log loss metric into an average probability that model classifies accurately
import math
test_prob = math.exp(-Logloss_vif)
train_prob = math.exp(-Logloss_train_vif)

# %%
print(test_prob, train_prob)
# Out:
# (0.6670397083839018, 0.882060894209717)

# %%
sns.set_style("whitegrid")

group_results2 = pd.DataFrame(data=group2)
group_results2.columns = ['Max_leaf_nodes','Test logloss','Train logloss',
                         'Average cross validation logloss','Std cross validation']
group_results2 = group_results2.set_index('Max_leaf_nodes')
group_results2['Average cross validation logloss'] = group_results2['Average cross validation logloss'] +1
group_results2
group_results2.plot()
plt.legend(loc = 'best')

# %%
sns.set_style("white")

feats3 = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(X_test_vif.columns, gbc2.feature_importances_):
    feats3[feature] = importance #add the name/value pair 

importances2 = pd.DataFrame.from_dict(feats3, orient='index').rename(columns={0: 'Importance'})
importances2 = importances2
importances2.sort_values(by='Importance', ascending=False)[:10].plot(kind='bar', rot=90, color=color)
plt.legend(loc = 'best')

# %% [markdown]
# **Plot Partial dependencies**

# %%
from sklearn.ensemble.partial_dependence import plot_partial_dependence
from sklearn.ensemble.partial_dependence import partial_dependence

# %%
names = X_train_vif.columns



features = [0, 1, 2, 3, 4, 5, 6, 7, 8]
fig, axs = plot_partial_dependence(gbc2, X_train_vif, features,
                                   feature_names=names,
                                   n_jobs=1, n_cols= 3, grid_resolution=100)
plt.subplots_adjust(left=None, bottom=None, right=1.2, top=2.2,
                wspace=1, hspace=1)

# %% [markdown]
# **Benchmark model**

# %%
# build logistic regression model
# address unbalanced classes with parameter 'class_weights'
from sklearn.linear_model import LogisticRegression


estimator = LogisticRegression(random_state=42, class_weight={0:1, 1:3.63728}, n_jobs=-1)

estimator.fit(X_train, y_train)

y_pred_regr = estimator.predict_proba(X_test)
y_pred_regr = pd.DataFrame(y_pred_regr, index=y_test.index)

y_pred_regr_train = estimator.predict_proba(X_train)
y_pred_regr_train = pd.DataFrame(y_pred_regr_train, index=y_train.index)

# how does the basic model perform?

LogLoss3 = log_loss(y_test, y_pred_regr[1])
Logloss_train3 = log_loss(y_train, y_pred_regr_train[1])

print("The logloss on the training set for a simple Logistic Regression model is {:.4f}.".format(Logloss_train3))
print("The logloss on the testing set for a simple Logistic Regression model is {:.4f}.".format(LogLoss3))
# Out:
# The logloss on the training set for a simple Logistic Regression model is 0.2164.
# The logloss on the testing set for a simple Logistic Regression model is 0.8327.

# %%
# transform log loss metric into an average probability that model classifies accurately
import math
test_prob_BM = math.exp(-LogLoss3)
train_prob_BM = math.exp(-Logloss_train3)
print(test_prob_BM, train_prob_BM)
# Out:
# (0.4348921695280084, 0.8054059262538517)
