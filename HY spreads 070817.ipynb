# %%
#import libraries
import pandas as pd
pd.set_option('display.max_columns', 999)
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette("hls", 20)

# %%
#import data
xls_file = pd.ExcelFile('C:\\Users\\sonja tilly.ABERDEEN\\data010817.xlsx')

# %% [markdown]
# **Prep data**

# %%
#parse sheet
data = xls_file.parse('data')
data.index = data['Date']
del data['Date']

# %%
#address data lags

def Shift(indicator, d):
    indicator.shift(d)
    return

data['CPI YOY Index'] = data['CPI YOY Index'].shift(11)
data['FDIDFDMO Index'] = data['FDIDFDMO Index'].shift(10)
data['USURTOT Index'] = data['NFP TCH Index'].shift(4)
data['NFP TCH Index'] = data['NFP TCH Index'].shift(4)
data['USEMNCHG Index'] = data['USEMNCHG Index'].shift(4)
data['IP CHNG Index'] = data['IP CHNG Index'].shift(17)
data['MTIBCHNG Index'] = data['MTIBCHNG Index'].shift(15)
data['MGT2TB Index'] = data['MGT2TB Index'].shift(15)
data['OUTFGAF Index'] = data['OUTFGAF Index'].shift(17)
data['USHBMIDX Index'] = data['USHBMIDX Index'].shift(15)
data['CONCCONF Index'] = data['CONCCONF Index'].shift(29)
data['RSTAMOM Index'] = data['RSTAMOM Index'].shift(15)
data['USTBTOT Index'] = data['USTBTOT Index'].shift(4)
data['CONSSENT Index'] = data['CONSSENT Index'].shift(18)
data['CICRTOT Index'] = data['CICRTOT Index'].shift(7)
data['SPE AUTO Index'] = data['SPE AUTO Index'].shift(30)
data['SPE CARD Index'] = data['SPE AUTO Index'].shift(30)
data['GDP CYOY Index'] = data['GDP CYOY Index'].shift(30)

data = data.fillna(0)
data.head(1)
# Out:
#             FDTR Index  VIX Index  USTW$ Index  USGG10YR Index  \
# Date
# 1997-01-01        5.25      20.92      88.4869            6.42
#
#             USGG30YR Index  USGG5YR Index  USYC2Y10 Index  USYC2Y30 Index  \
# Date
# 1997-01-01           6.641           6.21           48.45            70.6
#
#             USYC5Y10 Index  USYC2Y5Y Index  CPI YOY Index  FDIDFDMO Index  \
# Date
# 1997-01-01            14.0           34.45            0.0             0.0
#
#             USURTOT Index  NFP TCH Index  USEMNCHG Index  IP CHNG Index  \
# Date
# 1997-01-01            0.0            0.0             0.0            0.0
#
#             MTIBCHNG Index  MGT2TB Index  PIDSPINX Index  NAPMPMI Index  \
# Date
# 1997-01-01             0.0           0.0          7496.1           55.2
#
#             OUTFGAF Index  USGGBE10 Index  USHBMIDX Index  CONCCONF Index  \
# Date
# 1997-01-01            0.0             0.0             0.0             0.0
#
#             OEUSKLAR Index  RSTAMOM Index  USTBTOT Index  FDDSGDP Index  \
# Date
# 1997-01-01         73.0711            0.0            0.0           -1.3
#
#             M2% YOY Index  CLA Comdty  CONSSENT Index  PIDSDPS Index  \
# Date
# 1997-01-01            4.9         0.0             0.0            5.7
#
#             CICRTOT Index  ARDIMOYY Index  M1% YOY Index  SCGRRAI Index  \
# Date
# 1997-01-01            0.0            4.02           -4.1            0.0
#
#             EMB US Equity  SPE AUTO Index  SPE CARD Index  BFCIUS Index  \
# Date
# 1997-01-01            0.0             0.0             0.0         0.779
#
#             INJCJMOM Index  LEI CHNG Index  GDP CYOY Index  SLDETIGT Index  \
# Date
# 1997-01-01             7.5             0.1             0.0             0.0
#
#             SLDETGTS Index  GFSIFFND Index  XLF US Equity  XLE US Equity  \
# Date
# 1997-01-01             0.0             0.0            0.0            0.0
#
#             XLK US Equity  XLV US Equity  XLI US Equity  XLY US Equity  \
# Date
# 1997-01-01            0.0            0.0            0.0            0.0
#
#             XLB US Equity  CDX HY CDSI GEN 5Y SPRD Corp  PCUSEQTR Index  \
# Date
# 1997-01-01            0.0                           0.0             0.0
#
#             GFSIRLIQ Index  CIGMEMRA Index  CIGMGRAM Index  LF98OAS Index
# Date
# 1997-01-01             0.0             0.0             0.0           2.88

# %% [markdown]
# **Transform features**

# %%
#convert index to datetime object
data.index = pd.to_datetime(data.index)

# %%
# these are the transformations applied to each indicator
# the transformations of the n variables create n new columns of the transformed variable which then run through the classifiers
# add zscore formula to LevelChange and PctChange

from scipy import stats

window = [90, 180, 360]

def LevelChange (indicator, window): #calculate the monthly change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' change in '+str(window)+'ds']=data[indicator]-data[indicator].shift(days)
    data[str(indicator)+' change in '+str(window)+'ds' +'zscore']=stats.zscore(data[indicator], axis=None)
    
def PctChange (indicator,window): #calculate the monthly percentage change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' %change in '+str(window)+'ds']=data[indicator]/data[indicator].shift(days)-1
    data[str(indicator)+' change in '+str(window)+'ds' +'zscore']=stats.zscore(data[indicator], axis=None)
    
def Zscore (indicator,window):  # calculate a Z score over a number of trading days
    mean=data[indicator].rolling(window).mean()
    std=data[indicator].rolling(window).std()
    data[str(indicator)+str(window)+'zscore']=(data[indicator]-mean)/std

# %%
cols = list(data.columns)

for i in window:
    for col in cols:
        Zscore (col,i)

# %%
for i in window:
    LevelChange('FDTR Index', i)
    LevelChange('CPI YOY Index', i)
    LevelChange('IP CHNG Index', i)
    LevelChange('MGT2TB Index', i)
    LevelChange('NAPMPMI Index', i)
    LevelChange('OUTFGAF Index', i)
    LevelChange('USGGBE10 Index', i)
    LevelChange('USHBMIDX Index', i)
    LevelChange('CONCCONF Index', i)
    LevelChange('OEUSKLAR Index', i)
    LevelChange('FDDSGDP Index', i)
    LevelChange('M2% YOY Index', i)
    LevelChange('CONSSENT Index', i)
    LevelChange('PIDSDPS Index', i)
    LevelChange('CICRTOT Index', i)
    LevelChange('M1% YOY Index', i)
    LevelChange('SCGRRAI Index', i)
    LevelChange('LEI CHNG Index', i)
    LevelChange('GDP CYOY Index', i)
    LevelChange('GFSIFFND Index', i)
    LevelChange('CDX HY CDSI GEN 5Y SPRD Corp', i)
    LevelChange('PCUSEQTR Index', i)
    LevelChange('GFSIRLIQ Index', i)
    LevelChange('CIGMEMRA Index', i)
    LevelChange('CIGMGRAM Index', i)
    LevelChange('LF98OAS Index', i)

# %%
for i in window:
    PctChange('VIX Index',i)
    PctChange('USTW$ Index',i)
    PctChange('USGG10YR Index',i)
    PctChange('USGG30YR Index',i)
    PctChange('USGG5YR Index',i)
    PctChange('USYC2Y10 Index',i)
    PctChange('USYC2Y30 Index',i)
    PctChange('USYC5Y10 Index',i)
    PctChange('USYC2Y5Y Index',i)
    PctChange('FDIDFDMO Index',i)
    PctChange('USEMNCHG Index',i)
    PctChange('MTIBCHNG Index',i)
    PctChange('PIDSPINX Index',i)
    PctChange('RSTAMOM Index',i)
    PctChange('USTBTOT Index',i)
    PctChange('CLA Comdty',i)
    PctChange('ARDIMOYY Index',i)
    PctChange('EMB US Equity',i)
    PctChange('SPE AUTO Index',i)
    PctChange('SPE CARD Index',i)
    PctChange('BFCIUS Index',i)
    PctChange('INJCJMOM Index',i)
    PctChange('SLDETIGT Index',i)
    PctChange('SLDETGTS Index',i)
    PctChange('XLF US Equity',i)
    PctChange('XLE US Equity',i)
    PctChange('XLK US Equity',i)
    PctChange('XLV US Equity',i)
    PctChange('XLI US Equity',i)
    PctChange('XLY US Equity',i)
    PctChange('XLB US Equity',i)

# %%
data.head(1)
# Out:
#             FDTR Index  VIX Index  USTW$ Index  USGG10YR Index  \
# Date
# 1997-01-01        5.25      20.92      88.4869            6.42
#
#             USGG30YR Index  USGG5YR Index  USYC2Y10 Index  USYC2Y30 Index  \
# Date
# 1997-01-01           6.641           6.21           48.45            70.6
#
#             USYC5Y10 Index  USYC2Y5Y Index  CPI YOY Index  FDIDFDMO Index  \
# Date
# 1997-01-01            14.0           34.45            0.0             0.0
#
#             USURTOT Index  NFP TCH Index  USEMNCHG Index  IP CHNG Index  \
# Date
# 1997-01-01            0.0            0.0             0.0            0.0
#
#             MTIBCHNG Index  MGT2TB Index  PIDSPINX Index  NAPMPMI Index  \
# Date
# 1997-01-01             0.0           0.0          7496.1           55.2
#
#             OUTFGAF Index  USGGBE10 Index  USHBMIDX Index  CONCCONF Index  \
# Date
# 1997-01-01            0.0             0.0             0.0             0.0
#
#             OEUSKLAR Index  RSTAMOM Index  USTBTOT Index  FDDSGDP Index  \
# Date
# 1997-01-01         73.0711            0.0            0.0           -1.3
#
#             M2% YOY Index  CLA Comdty  CONSSENT Index  PIDSDPS Index  \
# Date
# 1997-01-01            4.9         0.0             0.0            5.7
#
#             CICRTOT Index  ARDIMOYY Index  M1% YOY Index  SCGRRAI Index  \
# Date
# 1997-01-01            0.0            4.02           -4.1            0.0
#
#             EMB US Equity  SPE AUTO Index  SPE CARD Index  BFCIUS Index  \
# Date
# 1997-01-01            0.0             0.0             0.0         0.779
#
#             INJCJMOM Index  LEI CHNG Index  GDP CYOY Index  SLDETIGT Index  \
# Date
# 1997-01-01             7.5             0.1             0.0             0.0
#
#             SLDETGTS Index  GFSIFFND Index  XLF US Equity  XLE US Equity  \
# Date
# 1997-01-01             0.0             0.0            0.0            0.0
#
#             XLK US Equity  XLV US Equity  XLI US Equity  XLY US Equity  \
# Date
# 1997-01-01            0.0            0.0            0.0            0.0
#
#             XLB US Equity  CDX HY CDSI GEN 5Y SPRD Corp  PCUSEQTR Index  \
# Date
# 1997-01-01            0.0                           0.0             0.0
#
#             GFSIRLIQ Index  CIGMEMRA Index  CIGMGRAM Index  LF98OAS Index  \
# Date
# 1997-01-01             0.0             0.0             0.0           2.88
#
#             FDTR Index90zscore  VIX Index90zscore  USTW$ Index90zscore  \
# Date
# 1997-01-01                 NaN                NaN                  NaN
#
#             USGG10YR Index90zscore  USGG30YR Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             USGG5YR Index90zscore  USYC2Y10 Index90zscore  \
# Date
# 1997-01-01                    NaN                     NaN
#
#             USYC2Y30 Index90zscore  USYC5Y10 Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             USYC2Y5Y Index90zscore  CPI YOY Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
#
#             FDIDFDMO Index90zscore  USURTOT Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
#
#             NFP TCH Index90zscore  USEMNCHG Index90zscore  \
# Date
# 1997-01-01                    NaN                     NaN
#
#             IP CHNG Index90zscore  MTIBCHNG Index90zscore  \
# Date
# 1997-01-01                    NaN                     NaN
#
#             MGT2TB Index90zscore  PIDSPINX Index90zscore  \
# Date
# 1997-01-01                   NaN                     NaN
#
#             NAPMPMI Index90zscore  OUTFGAF Index90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
#
#             USGGBE10 Index90zscore  USHBMIDX Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             CONCCONF Index90zscore  OEUSKLAR Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             RSTAMOM Index90zscore  USTBTOT Index90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
#
#             FDDSGDP Index90zscore  M2% YOY Index90zscore  CLA Comdty90zscore  \
# Date
# 1997-01-01                    NaN                    NaN                 NaN
#
#             CONSSENT Index90zscore  PIDSDPS Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
#
#             CICRTOT Index90zscore  ARDIMOYY Index90zscore  \
# Date
# 1997-01-01                    NaN                     NaN
#
#             M1% YOY Index90zscore  SCGRRAI Index90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
#
#             EMB US Equity90zscore  SPE AUTO Index90zscore  \
# Date
# 1997-01-01                    NaN                     NaN
#
#             SPE CARD Index90zscore  BFCIUS Index90zscore  \
# Date
# 1997-01-01                     NaN                   NaN
#
#             INJCJMOM Index90zscore  LEI CHNG Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             GDP CYOY Index90zscore  SLDETIGT Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             SLDETGTS Index90zscore  GFSIFFND Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             XLF US Equity90zscore  XLE US Equity90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
#
#             XLK US Equity90zscore  XLV US Equity90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
#
#             XLI US Equity90zscore  XLY US Equity90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
#
#             XLB US Equity90zscore  CDX HY CDSI GEN 5Y SPRD Corp90zscore  \
# Date
# 1997-01-01                    NaN                                   NaN
#
#             PCUSEQTR Index90zscore  GFSIRLIQ Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             CIGMEMRA Index90zscore  CIGMGRAM Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             LF98OAS Index90zscore  FDTR Index180zscore  VIX Index180zscore  \
# Date
# 1997-01-01                    NaN                  NaN                 NaN
#
#             USTW$ Index180zscore  USGG10YR Index180zscore  \
# Date
# 1997-01-01                   NaN                      NaN
#
#             USGG30YR Index180zscore  USGG5YR Index180zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             USYC2Y10 Index180zscore  USYC2Y30 Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             USYC5Y10 Index180zscore  USYC2Y5Y Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             CPI YOY Index180zscore  FDIDFDMO Index180zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             USURTOT Index180zscore  NFP TCH Index180zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             USEMNCHG Index180zscore  IP CHNG Index180zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             MTIBCHNG Index180zscore  MGT2TB Index180zscore  \
# Date
# 1997-01-01                      NaN                    NaN
#
#             PIDSPINX Index180zscore  NAPMPMI Index180zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             OUTFGAF Index180zscore  USGGBE10 Index180zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             USHBMIDX Index180zscore  CONCCONF Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             OEUSKLAR Index180zscore  RSTAMOM Index180zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             USTBTOT Index180zscore  FDDSGDP Index180zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             M2% YOY Index180zscore  CLA Comdty180zscore  \
# Date
# 1997-01-01                     NaN                  NaN
#
#             CONSSENT Index180zscore  PIDSDPS Index180zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             CICRTOT Index180zscore  ARDIMOYY Index180zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             M1% YOY Index180zscore  SCGRRAI Index180zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             EMB US Equity180zscore  SPE AUTO Index180zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             SPE CARD Index180zscore  BFCIUS Index180zscore  \
# Date
# 1997-01-01                      NaN                    NaN
#
#             INJCJMOM Index180zscore  LEI CHNG Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             GDP CYOY Index180zscore  SLDETIGT Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             SLDETGTS Index180zscore  GFSIFFND Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             XLF US Equity180zscore  XLE US Equity180zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             XLK US Equity180zscore  XLV US Equity180zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             XLI US Equity180zscore  XLY US Equity180zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             XLB US Equity180zscore  CDX HY CDSI GEN 5Y SPRD Corp180zscore  \
# Date
# 1997-01-01                     NaN                                    NaN
#
#             PCUSEQTR Index180zscore  GFSIRLIQ Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             CIGMEMRA Index180zscore  CIGMGRAM Index180zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             LF98OAS Index180zscore  FDTR Index360zscore  VIX Index360zscore  \
# Date
# 1997-01-01                     NaN                  NaN                 NaN
#
#             USTW$ Index360zscore  USGG10YR Index360zscore  \
# Date
# 1997-01-01                   NaN                      NaN
#
#             USGG30YR Index360zscore  USGG5YR Index360zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             USYC2Y10 Index360zscore  USYC2Y30 Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             USYC5Y10 Index360zscore  USYC2Y5Y Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             CPI YOY Index360zscore  FDIDFDMO Index360zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             USURTOT Index360zscore  NFP TCH Index360zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             USEMNCHG Index360zscore  IP CHNG Index360zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             MTIBCHNG Index360zscore  MGT2TB Index360zscore  \
# Date
# 1997-01-01                      NaN                    NaN
#
#             PIDSPINX Index360zscore  NAPMPMI Index360zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             OUTFGAF Index360zscore  USGGBE10 Index360zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             USHBMIDX Index360zscore  CONCCONF Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             OEUSKLAR Index360zscore  RSTAMOM Index360zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             USTBTOT Index360zscore  FDDSGDP Index360zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             M2% YOY Index360zscore  CLA Comdty360zscore  \
# Date
# 1997-01-01                     NaN                  NaN
#
#             CONSSENT Index360zscore  PIDSDPS Index360zscore  \
# Date
# 1997-01-01                      NaN                     NaN
#
#             CICRTOT Index360zscore  ARDIMOYY Index360zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             M1% YOY Index360zscore  SCGRRAI Index360zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             EMB US Equity360zscore  SPE AUTO Index360zscore  \
# Date
# 1997-01-01                     NaN                      NaN
#
#             SPE CARD Index360zscore  BFCIUS Index360zscore  \
# Date
# 1997-01-01                      NaN                    NaN
#
#             INJCJMOM Index360zscore  LEI CHNG Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             GDP CYOY Index360zscore  SLDETIGT Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             SLDETGTS Index360zscore  GFSIFFND Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             XLF US Equity360zscore  XLE US Equity360zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             XLK US Equity360zscore  XLV US Equity360zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             XLI US Equity360zscore  XLY US Equity360zscore  \
# Date
# 1997-01-01                     NaN                     NaN
#
#             XLB US Equity360zscore  CDX HY CDSI GEN 5Y SPRD Corp360zscore  \
# Date
# 1997-01-01                     NaN                                    NaN
#
#             PCUSEQTR Index360zscore  GFSIRLIQ Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             CIGMEMRA Index360zscore  CIGMGRAM Index360zscore  \
# Date
# 1997-01-01                      NaN                      NaN
#
#             LF98OAS Index360zscore  FDTR Index change in 90ds  \
# Date
# 1997-01-01                     NaN                        NaN
#
#             FDTR Index change in 90dszscore  CPI YOY Index change in 90ds  \
# Date
# 1997-01-01                          1.32175                           NaN
#
#             CPI YOY Index change in 90dszscore  IP CHNG Index change in 90ds  \
# Date
# 1997-01-01                           -1.745033                           NaN
#
#             IP CHNG Index change in 90dszscore  MGT2TB Index change in 90ds  \
# Date
# 1997-01-01                           -0.175857                          NaN
#
#             MGT2TB Index change in 90dszscore  NAPMPMI Index change in 90ds  \
# Date
# 1997-01-01                         -15.169804                           NaN
#
#             NAPMPMI Index change in 90dszscore  OUTFGAF Index change in 90ds  \
# Date
# 1997-01-01                             0.60125                           NaN
#
#             OUTFGAF Index change in 90dszscore  USGGBE10 Index change in 90ds  \
# Date
# 1997-01-01                           -0.453723                            NaN
#
#             USGGBE10 Index change in 90dszscore  \
# Date
# 1997-01-01                              -2.7279
#
#             USHBMIDX Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             USHBMIDX Index change in 90dszscore  \
# Date
# 1997-01-01                            -2.402148
#
#             CONCCONF Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             CONCCONF Index change in 90dszscore  \
# Date
# 1997-01-01                            -3.278309
#
#             OEUSKLAR Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             OEUSKLAR Index change in 90dszscore  FDDSGDP Index change in 90ds  \
# Date
# 1997-01-01                            -2.079339                           NaN
#
#             FDDSGDP Index change in 90dszscore  M2% YOY Index change in 90ds  \
# Date
# 1997-01-01                            0.477291                           NaN
#
#             M2% YOY Index change in 90dszscore  CONSSENT Index change in 90ds  \
# Date
# 1997-01-01                           -0.854533                            NaN
#
#             CONSSENT Index change in 90dszscore  PIDSDPS Index change in 90ds  \
# Date
# 1997-01-01                            -6.178746                           NaN
#
#             PIDSDPS Index change in 90dszscore  CICRTOT Index change in 90ds  \
# Date
# 1997-01-01                            0.551394                           NaN
#
#             CICRTOT Index change in 90dszscore  M1% YOY Index change in 90ds  \
# Date
# 1997-01-01                           -1.215515                           NaN
#
#             M1% YOY Index change in 90dszscore  SCGRRAI Index change in 90ds  \
# Date
# 1997-01-01                           -1.745268                           NaN
#
#             SCGRRAI Index change in 90dszscore  LEI CHNG Index change in 90ds  \
# Date
# 1997-01-01                           -0.127738                            NaN
#
#             LEI CHNG Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.015249
#
#             GDP CYOY Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             GDP CYOY Index change in 90dszscore  \
# Date
# 1997-01-01                            -1.269784
#
#             GFSIFFND Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             GFSIFFND Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.127396
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 90ds  \
# Date
# 1997-01-01                                          NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 90dszscore  \
# Date
# 1997-01-01                                          -0.555792
#
#             PCUSEQTR Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             PCUSEQTR Index change in 90dszscore  \
# Date
# 1997-01-01                            -4.237662
#
#             GFSIRLIQ Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             GFSIRLIQ Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.440187
#
#             CIGMEMRA Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             CIGMEMRA Index change in 90dszscore  \
# Date
# 1997-01-01                             0.091362
#
#             CIGMGRAM Index change in 90ds  \
# Date
# 1997-01-01                            NaN
#
#             CIGMGRAM Index change in 90dszscore  LF98OAS Index change in 90ds  \
# Date
# 1997-01-01                            -0.090241                           NaN
#
#             LF98OAS Index change in 90dszscore  FDTR Index change in 180ds  \
# Date
# 1997-01-01                           -1.018619                         NaN
#
#             FDTR Index change in 180dszscore  CPI YOY Index change in 180ds  \
# Date
# 1997-01-01                           1.32175                            NaN
#
#             CPI YOY Index change in 180dszscore  \
# Date
# 1997-01-01                            -1.745033
#
#             IP CHNG Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             IP CHNG Index change in 180dszscore  MGT2TB Index change in 180ds  \
# Date
# 1997-01-01                            -0.175857                           NaN
#
#             MGT2TB Index change in 180dszscore  NAPMPMI Index change in 180ds  \
# Date
# 1997-01-01                          -15.169804                            NaN
#
#             NAPMPMI Index change in 180dszscore  \
# Date
# 1997-01-01                              0.60125
#
#             OUTFGAF Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             OUTFGAF Index change in 180dszscore  \
# Date
# 1997-01-01                            -0.453723
#
#             USGGBE10 Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             USGGBE10 Index change in 180dszscore  \
# Date
# 1997-01-01                               -2.7279
#
#             USHBMIDX Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             USHBMIDX Index change in 180dszscore  \
# Date
# 1997-01-01                             -2.402148
#
#             CONCCONF Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             CONCCONF Index change in 180dszscore  \
# Date
# 1997-01-01                             -3.278309
#
#             OEUSKLAR Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             OEUSKLAR Index change in 180dszscore  \
# Date
# 1997-01-01                             -2.079339
#
#             FDDSGDP Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             FDDSGDP Index change in 180dszscore  \
# Date
# 1997-01-01                             0.477291
#
#             M2% YOY Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             M2% YOY Index change in 180dszscore  \
# Date
# 1997-01-01                            -0.854533
#
#             CONSSENT Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             CONSSENT Index change in 180dszscore  \
# Date
# 1997-01-01                             -6.178746
#
#             PIDSDPS Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             PIDSDPS Index change in 180dszscore  \
# Date
# 1997-01-01                             0.551394
#
#             CICRTOT Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             CICRTOT Index change in 180dszscore  \
# Date
# 1997-01-01                            -1.215515
#
#             M1% YOY Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             M1% YOY Index change in 180dszscore  \
# Date
# 1997-01-01                            -1.745268
#
#             SCGRRAI Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             SCGRRAI Index change in 180dszscore  \
# Date
# 1997-01-01                            -0.127738
#
#             LEI CHNG Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             LEI CHNG Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.015249
#
#             GDP CYOY Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             GDP CYOY Index change in 180dszscore  \
# Date
# 1997-01-01                             -1.269784
#
#             GFSIFFND Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             GFSIFFND Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.127396
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 180ds  \
# Date
# 1997-01-01                                           NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 180dszscore  \
# Date
# 1997-01-01                                          -0.555792
#
#             PCUSEQTR Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             PCUSEQTR Index change in 180dszscore  \
# Date
# 1997-01-01                             -4.237662
#
#             GFSIRLIQ Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             GFSIRLIQ Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.440187
#
#             CIGMEMRA Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             CIGMEMRA Index change in 180dszscore  \
# Date
# 1997-01-01                              0.091362
#
#             CIGMGRAM Index change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             CIGMGRAM Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.090241
#
#             LF98OAS Index change in 180ds  \
# Date
# 1997-01-01                            NaN
#
#             LF98OAS Index change in 180dszscore  FDTR Index change in 360ds  \
# Date
# 1997-01-01                            -1.018619                         NaN
#
#             FDTR Index change in 360dszscore  CPI YOY Index change in 360ds  \
# Date
# 1997-01-01                           1.32175                            NaN
#
#             CPI YOY Index change in 360dszscore  \
# Date
# 1997-01-01                            -1.745033
#
#             IP CHNG Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             IP CHNG Index change in 360dszscore  MGT2TB Index change in 360ds  \
# Date
# 1997-01-01                            -0.175857                           NaN
#
#             MGT2TB Index change in 360dszscore  NAPMPMI Index change in 360ds  \
# Date
# 1997-01-01                          -15.169804                            NaN
#
#             NAPMPMI Index change in 360dszscore  \
# Date
# 1997-01-01                              0.60125
#
#             OUTFGAF Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             OUTFGAF Index change in 360dszscore  \
# Date
# 1997-01-01                            -0.453723
#
#             USGGBE10 Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             USGGBE10 Index change in 360dszscore  \
# Date
# 1997-01-01                               -2.7279
#
#             USHBMIDX Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             USHBMIDX Index change in 360dszscore  \
# Date
# 1997-01-01                             -2.402148
#
#             CONCCONF Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             CONCCONF Index change in 360dszscore  \
# Date
# 1997-01-01                             -3.278309
#
#             OEUSKLAR Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             OEUSKLAR Index change in 360dszscore  \
# Date
# 1997-01-01                             -2.079339
#
#             FDDSGDP Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             FDDSGDP Index change in 360dszscore  \
# Date
# 1997-01-01                             0.477291
#
#             M2% YOY Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             M2% YOY Index change in 360dszscore  \
# Date
# 1997-01-01                            -0.854533
#
#             CONSSENT Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             CONSSENT Index change in 360dszscore  \
# Date
# 1997-01-01                             -6.178746
#
#             PIDSDPS Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             PIDSDPS Index change in 360dszscore  \
# Date
# 1997-01-01                             0.551394
#
#             CICRTOT Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             CICRTOT Index change in 360dszscore  \
# Date
# 1997-01-01                            -1.215515
#
#             M1% YOY Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             M1% YOY Index change in 360dszscore  \
# Date
# 1997-01-01                            -1.745268
#
#             SCGRRAI Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             SCGRRAI Index change in 360dszscore  \
# Date
# 1997-01-01                            -0.127738
#
#             LEI CHNG Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             LEI CHNG Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.015249
#
#             GDP CYOY Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             GDP CYOY Index change in 360dszscore  \
# Date
# 1997-01-01                             -1.269784
#
#             GFSIFFND Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             GFSIFFND Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.127396
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 360ds  \
# Date
# 1997-01-01                                           NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 360dszscore  \
# Date
# 1997-01-01                                          -0.555792
#
#             PCUSEQTR Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             PCUSEQTR Index change in 360dszscore  \
# Date
# 1997-01-01                             -4.237662
#
#             GFSIRLIQ Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             GFSIRLIQ Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.440187
#
#             CIGMEMRA Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             CIGMEMRA Index change in 360dszscore  \
# Date
# 1997-01-01                              0.091362
#
#             CIGMGRAM Index change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             CIGMGRAM Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.090241
#
#             LF98OAS Index change in 360ds  \
# Date
# 1997-01-01                            NaN
#
#             LF98OAS Index change in 360dszscore  VIX Index %change in 90ds  \
# Date
# 1997-01-01                            -1.018619                        NaN
#
#             VIX Index change in 90dszscore  USTW$ Index %change in 90ds  \
# Date
# 1997-01-01                        0.038014                          NaN
#
#             USTW$ Index change in 90dszscore  USGG10YR Index %change in 90ds  \
# Date
# 1997-01-01                          0.127998                             NaN
#
#             USGG10YR Index change in 90dszscore  \
# Date
# 1997-01-01                             1.805326
#
#             USGG30YR Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             USGG30YR Index change in 90dszscore  \
# Date
# 1997-01-01                             1.869981
#
#             USGG5YR Index %change in 90ds  USGG5YR Index change in 90dszscore  \
# Date
# 1997-01-01                            NaN                             1.70684
#
#             USYC2Y10 Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             USYC2Y10 Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.845785
#
#             USYC2Y30 Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             USYC2Y30 Index change in 90dszscore  \
# Date
# 1997-01-01                             -0.93732
#
#             USYC5Y10 Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             USYC5Y10 Index change in 90dszscore  \
# Date
# 1997-01-01                            -1.069851
#
#             USYC2Y5Y Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             USYC2Y5Y Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.586487
#
#             FDIDFDMO Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             FDIDFDMO Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.279704
#
#             USEMNCHG Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             USEMNCHG Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.299637
#
#             MTIBCHNG Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             MTIBCHNG Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.469301
#
#             PIDSPINX Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             PIDSPINX Index change in 90dszscore  \
# Date
# 1997-01-01                            -2.215765
#
#             RSTAMOM Index %change in 90ds  RSTAMOM Index change in 90dszscore  \
# Date
# 1997-01-01                            NaN                           -0.315759
#
#             USTBTOT Index %change in 90ds  USTBTOT Index change in 90dszscore  \
# Date
# 1997-01-01                            NaN                            2.739191
#
#             CLA Comdty %change in 90ds  CLA Comdty change in 90dszscore  \
# Date
# 1997-01-01                         NaN                        -0.597869
#
#             ARDIMOYY Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             ARDIMOYY Index change in 90dszscore  \
# Date
# 1997-01-01                            -0.384094
#
#             EMB US Equity %change in 90ds  EMB US Equity change in 90dszscore  \
# Date
# 1997-01-01                            NaN                           -0.931775
#
#             SPE AUTO Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             SPE AUTO Index change in 90dszscore  \
# Date
# 1997-01-01                             -1.13246
#
#             SPE CARD Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             SPE CARD Index change in 90dszscore  BFCIUS Index %change in 90ds  \
# Date
# 1997-01-01                            -1.125592                           NaN
#
#             BFCIUS Index change in 90dszscore  INJCJMOM Index %change in 90ds  \
# Date
# 1997-01-01                           0.831488                             NaN
#
#             INJCJMOM Index change in 90dszscore  \
# Date
# 1997-01-01                             1.242249
#
#             SLDETIGT Index %change in 90ds  \
# Date
# 1997-01-01                             NaN
#
#             SLDETIGT Index change in 90dszscore  \
# Date
# ...
# Date
# 1997-01-01                              -0.93732
#
#             USYC5Y10 Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             USYC5Y10 Index change in 180dszscore  \
# Date
# 1997-01-01                             -1.069851
#
#             USYC2Y5Y Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             USYC2Y5Y Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.586487
#
#             FDIDFDMO Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             FDIDFDMO Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.279704
#
#             USEMNCHG Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             USEMNCHG Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.299637
#
#             MTIBCHNG Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             MTIBCHNG Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.469301
#
#             PIDSPINX Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             PIDSPINX Index change in 180dszscore  \
# Date
# 1997-01-01                             -2.215765
#
#             RSTAMOM Index %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             RSTAMOM Index change in 180dszscore  \
# Date
# 1997-01-01                            -0.315759
#
#             USTBTOT Index %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             USTBTOT Index change in 180dszscore  CLA Comdty %change in 180ds  \
# Date
# 1997-01-01                             2.739191                          NaN
#
#             CLA Comdty change in 180dszscore  ARDIMOYY Index %change in 180ds  \
# Date
# 1997-01-01                         -0.597869                              NaN
#
#             ARDIMOYY Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.384094
#
#             EMB US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             EMB US Equity change in 180dszscore  \
# Date
# 1997-01-01                            -0.931775
#
#             SPE AUTO Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             SPE AUTO Index change in 180dszscore  \
# Date
# 1997-01-01                              -1.13246
#
#             SPE CARD Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             SPE CARD Index change in 180dszscore  \
# Date
# 1997-01-01                             -1.125592
#
#             BFCIUS Index %change in 180ds  BFCIUS Index change in 180dszscore  \
# Date
# 1997-01-01                            NaN                            0.831488
#
#             INJCJMOM Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             INJCJMOM Index change in 180dszscore  \
# Date
# 1997-01-01                              1.242249
#
#             SLDETIGT Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             SLDETIGT Index change in 180dszscore  \
# Date
# 1997-01-01                              -0.27285
#
#             SLDETGTS Index %change in 180ds  \
# Date
# 1997-01-01                              NaN
#
#             SLDETGTS Index change in 180dszscore  \
# Date
# 1997-01-01                             -0.309492
#
#             XLF US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             XLF US Equity change in 180dszscore  \
# Date
# 1997-01-01                            -2.293822
#
#             XLE US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             XLE US Equity change in 180dszscore  \
# Date
# 1997-01-01                            -1.893171
#
#             XLK US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             XLK US Equity change in 180dszscore  \
# Date
# 1997-01-01                            -1.935519
#
#             XLV US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             XLV US Equity change in 180dszscore  \
# Date
# 1997-01-01                            -1.861202
#
#             XLI US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             XLI US Equity change in 180dszscore  \
# Date
# 1997-01-01                            -2.096383
#
#             XLY US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             XLY US Equity change in 180dszscore  \
# Date
# 1997-01-01                            -1.714307
#
#             XLB US Equity %change in 180ds  \
# Date
# 1997-01-01                             NaN
#
#             XLB US Equity change in 180dszscore  VIX Index %change in 360ds  \
# Date
# 1997-01-01                            -2.209385                         NaN
#
#             VIX Index change in 360dszscore  USTW$ Index %change in 360ds  \
# Date
# 1997-01-01                         0.038014                           NaN
#
#             USTW$ Index change in 360dszscore  \
# Date
# 1997-01-01                           0.127998
#
#             USGG10YR Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             USGG10YR Index change in 360dszscore  \
# Date
# 1997-01-01                              1.805326
#
#             USGG30YR Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             USGG30YR Index change in 360dszscore  \
# Date
# 1997-01-01                              1.869981
#
#             USGG5YR Index %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             USGG5YR Index change in 360dszscore  \
# Date
# 1997-01-01                              1.70684
#
#             USYC2Y10 Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             USYC2Y10 Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.845785
#
#             USYC2Y30 Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             USYC2Y30 Index change in 360dszscore  \
# Date
# 1997-01-01                              -0.93732
#
#             USYC5Y10 Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             USYC5Y10 Index change in 360dszscore  \
# Date
# 1997-01-01                             -1.069851
#
#             USYC2Y5Y Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             USYC2Y5Y Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.586487
#
#             FDIDFDMO Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             FDIDFDMO Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.279704
#
#             USEMNCHG Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             USEMNCHG Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.299637
#
#             MTIBCHNG Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             MTIBCHNG Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.469301
#
#             PIDSPINX Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             PIDSPINX Index change in 360dszscore  \
# Date
# 1997-01-01                             -2.215765
#
#             RSTAMOM Index %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             RSTAMOM Index change in 360dszscore  \
# Date
# 1997-01-01                            -0.315759
#
#             USTBTOT Index %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             USTBTOT Index change in 360dszscore  CLA Comdty %change in 360ds  \
# Date
# 1997-01-01                             2.739191                          NaN
#
#             CLA Comdty change in 360dszscore  ARDIMOYY Index %change in 360ds  \
# Date
# 1997-01-01                         -0.597869                              NaN
#
#             ARDIMOYY Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.384094
#
#             EMB US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             EMB US Equity change in 360dszscore  \
# Date
# 1997-01-01                            -0.931775
#
#             SPE AUTO Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             SPE AUTO Index change in 360dszscore  \
# Date
# 1997-01-01                              -1.13246
#
#             SPE CARD Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             SPE CARD Index change in 360dszscore  \
# Date
# 1997-01-01                             -1.125592
#
#             BFCIUS Index %change in 360ds  BFCIUS Index change in 360dszscore  \
# Date
# 1997-01-01                            NaN                            0.831488
#
#             INJCJMOM Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             INJCJMOM Index change in 360dszscore  \
# Date
# 1997-01-01                              1.242249
#
#             SLDETIGT Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             SLDETIGT Index change in 360dszscore  \
# Date
# 1997-01-01                              -0.27285
#
#             SLDETGTS Index %change in 360ds  \
# Date
# 1997-01-01                              NaN
#
#             SLDETGTS Index change in 360dszscore  \
# Date
# 1997-01-01                             -0.309492
#
#             XLF US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             XLF US Equity change in 360dszscore  \
# Date
# 1997-01-01                            -2.293822
#
#             XLE US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             XLE US Equity change in 360dszscore  \
# Date
# 1997-01-01                            -1.893171
#
#             XLK US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             XLK US Equity change in 360dszscore  \
# Date
# 1997-01-01                            -1.935519
#
#             XLV US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             XLV US Equity change in 360dszscore  \
# Date
# 1997-01-01                            -1.861202
#
#             XLI US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             XLI US Equity change in 360dszscore  \
# Date
# 1997-01-01                            -2.096383
#
#             XLY US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             XLY US Equity change in 360dszscore  \
# Date
# 1997-01-01                            -1.714307
#
#             XLB US Equity %change in 360ds  \
# Date
# 1997-01-01                             NaN
#
#             XLB US Equity change in 360dszscore
# Date
# 1997-01-01                            -2.209385

# %% [markdown]
# **Define input and target variables**

# %%
y = data['LF98OAS Index change in 90ds']

#LF98OAS Index
#LF98OAS Index90zscore
#LF98OAS Index180zscore
#LF98OAS Index360zscore
#LF98OAS Index change in 90dszscore
#LF98OAS Index change in 180dszscore
#LF98OAS Index change in 360dszscore

X = data.drop(['LF98OAS Index', 'LF98OAS Index change in 90ds','LF98OAS Index change in 180ds',\
          'LF98OAS Index change in 360ds', 'LF98OAS Index90zscore',\
         'LF98OAS Index180zscore', 'LF98OAS Index360zscore',\
          'LF98OAS Index change in 90dszscore',\
         'LF98OAS Index change in 180dszscore', 'LF98OAS Index change in 360dszscore'],axis=1)

# %%
#check if X contains any column related to target variable

cols = list(X.columns)

for col in cols:
    if "LF98OAS" in col:
        print (col)

# %%
#address inf and nan values
X = X.replace([np.inf, -np.inf], np.nan).fillna(0)
y = y.replace([np.inf, -np.inf], np.nan).fillna(0)

# %%
#split out training and testing sets

X_train = X[:6015]
y_train = y[:6015]
X_test = X[6015:]
y_test = y[6015:]
y_test.head()
# Out:
# Date
# 2013-06-21    0.31
# 2013-06-22    0.31
# 2013-06-23    0.31
# 2013-06-24    0.51
# 2013-06-25    0.48
# Name: LF98OAS Index change in 90ds, dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor  

def calculate_vif_(d, thresh=5.0):
    variables = d.columns
    dropped=True
    while dropped:
        dropped=False
        vif = pd.DataFrame()
        vif["VIF Factor"] = [variance_inflation_factor(d[variables].values, i) for i in range(d[variables].shape[1])]
        vif["features"] = d[variables].columns
        v=vif[vif["VIF Factor"]>thresh]
        
        if len(v) > 0:
            maxloc = v.iloc[len(v)-1]['features']
            print('dropping \'' + maxloc) 
            variables=variables.drop(maxloc)
            dropped=True

    print('Remaining variables:')
    print(d.columns)
    return d[variables]

X1 = calculate_vif_(X, thresh=5.0)
# Out:
# C:\Users\sonja tilly.ABERDEEN\AppData\Local\Continuum\Anaconda2\envs\py35\lib\site-packages\statsmodels\stats\outliers_influence.py:167: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
# dropping 'XLB US Equity change in 360dszscore

# %%
X_train2 = X_train[X1.columns]
X_test2 = X_test[X1.columns]
X_train2.head(1)

# %%
#try RandomForests

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

tree = RandomForestRegressor(n_jobs=-1, random_state=42) 

# use a full grid over all parameters
param_grid = {"max_depth": [6],
              "max_features": [24,28,32,36,40],
              "min_samples_split": [10,20],
              "min_samples_leaf": [1,3,5,6],
              "n_estimators":[13,14,15],
              "bootstrap": [True, False],
              }

CV_tree = GridSearchCV(estimator=tree, param_grid=param_grid, cv= 5)
CV_tree.fit(X_train2, y_train)
print(CV_tree.best_params_)
print(CV_tree.best_estimator_)

# %%
best_tree = CV_tree.best_estimator_

pred = (best_tree.fit(X_train2, y_train))

best_score_tree = best_tree.score(X_test2, y_test)
best_score_tree

# %%
feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(X_test2.columns, best_tree.feature_importances_):
    feats[feature] = importance #add the name/value pair 

importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Importance'})
importances = importances[:20]
importances.sort_values(by='Importance', ascending=False).plot(kind='bar', rot=90, color=color)

# %%
#try Gradient Boosted Trees

from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()

# use a full grid over all parameters

param_grid = {'learning_rate':[0.1, 0.05,0.01], 
             'n_estimators':[20,40,80], 
             'subsample':1.0, 
             'criterion':friedman_mse,
             'min_samples_split':2,
             'min_samples_leaf':1, 
             'min_weight_fraction_leaf':0.0, 
             'max_depth':[3,6,9,12],
             'random_state':42,
             'max_features':None,
             'alpha':0.9,
             'max_leaf_nodes':None,
             }

CV_gbr = GridSearchCV(estimator=gbr, param_grid=param_grid, cv= 5)
CV_gbr.fit(X_train2, y_train)
print(CV_gbr.best_params_)
print(CV_gbr.best_estimator_)

# %%
best_gbr = CV_gbr.best_estimator_

best_score_gbr = best_gbr.score(X_test2, y_test)
best_score_gbr

# %% [raw]
# feats = {} # a dict to hold feature_name: feature_importance
# for feature, importance in zip(X_test2.columns, best_gbr.feature_importances_):
#     feats[feature] = importance #add the name/value pair
#
# importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Importance'})
# importances = importances[:20]
# importances.sort_values(by='Importance', ascending=False).plot(kind='bar', rot=90, color=color)

# %%
#try Lasso regression

from sklearn import linear_model

lasso = linear_model.Lasso(alpha=0.1)
lasso.fit(X_train2, y_train)
lasso_score = lasso.score(X_test2,y_test)

#for i in alpha:
#    print lasso_sccore
