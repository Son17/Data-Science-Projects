# %%
#import libraries
import pandas as pd
pd.set_option('display.max_columns', 999)
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette("hls", 20)

# %%
#import data
xls_file = pd.ExcelFile('C:\\Users\\sonja tilly.ABERDEEN\\data260917.xlsx')

# %% [markdown]
# **Prep data**

# %%
#parse sheet
data = xls_file.parse('data')
data.index = data['Date']
del data['Date']
data.shape
# Out:
# (7574, 59)

# %%
data.columns
# Out:
# Index(['FDTR Index', 'VIX Index', 'USTW$ Index', 'USGG10YR Index',
#        'USGG30YR Index', 'USGG5YR Index', 'USYC2Y10 Index', 'USYC2Y30 Index',
#        'USYC5Y10 Index', 'USYC2Y5Y Index', 'CPI YOY Index', 'FDIDFDMO Index',
#        'USURTOT Index', 'NFP TCH Index', 'USEMNCHG Index', 'IP CHNG Index',
#        'MTIBCHNG Index', 'MGT2TB Index', 'PIDSPINX Index', 'NAPMPMI Index',
#        'OUTFGAF Index', 'USGGBE10 Index', 'USHBMIDX Index', 'CONCCONF Index',
#        'OEUSKLAR Index', 'RSTAMOM Index', 'USTBTOT Index', 'FDDSGDP Index',
#        'M2% YOY Index', 'CLA Comdty', 'CONSSENT Index', 'PIDSDPS Index',
#        'CICRTOT Index', 'ARDIMOYY Index', 'M1% YOY Index', 'SCGRRAI Index',
#        'EMB US Equity', 'SPE AUTO Index', 'SPE CARD Index', 'BFCIUS Index',
#        'INJCJMOM Index', 'LEI CHNG Index', 'GDP CYOY Index', 'SLDETIGT Index',
#        'SLDETGTS Index', 'GFSIFFND Index', 'XLF US Equity', 'XLE US Equity',
#        'XLK US Equity', 'XLV US Equity', 'XLI US Equity', 'XLY US Equity',
#        'XLB US Equity', 'CDX HY CDSI GEN 5Y SPRD Corp', 'PCUSEQTR Index',
#        'GFSIRLIQ Index', 'CIGMEMRA Index', 'CIGMGRAM Index', 'LF98OAS Index'],
#       dtype='object')

# %%
#address data lags

#def Shift(indicator, d):
#    indicator.shift(d)
#    return

data['CPI YOY Index'] = data['CPI YOY Index'].shift(11)
data['FDIDFDMO Index'] = data['FDIDFDMO Index'].shift(10)
data['USURTOT Index'] = data['NFP TCH Index'].shift(4)
data['NFP TCH Index'] = data['NFP TCH Index'].shift(4)
data['USEMNCHG Index'] = data['USEMNCHG Index'].shift(4)
data['IP CHNG Index'] = data['IP CHNG Index'].shift(17)
data['MTIBCHNG Index'] = data['MTIBCHNG Index'].shift(15)
data['MGT2TB Index'] = data['MGT2TB Index'].shift(15)
data['OUTFGAF Index'] = data['OUTFGAF Index'].shift(17)
data['USHBMIDX Index'] = data['USHBMIDX Index'].shift(15)
data['CONCCONF Index'] = data['CONCCONF Index'].shift(29)
data['RSTAMOM Index'] = data['RSTAMOM Index'].shift(15)
data['USTBTOT Index'] = data['USTBTOT Index'].shift(4)
data['CONSSENT Index'] = data['CONSSENT Index'].shift(18)
data['CICRTOT Index'] = data['CICRTOT Index'].shift(7)
data['SPE AUTO Index'] = data['SPE AUTO Index'].shift(30)
data['SPE CARD Index'] = data['SPE CARD Index'].shift(30)
data['GDP CYOY Index'] = data['GDP CYOY Index'].shift(30)

data = data.fillna(0)
data.shape
# Out:
# (7574, 59)

# %% [markdown]
# **Transform features**

# %%
#convert index to datetime object
data.index = pd.to_datetime(data.index)

# %%
# these are the transformations applied to each indicator
# the transformations of the n variables create n new columns of the transformed variable which then run through the classifiers
# add zscore formula to LevelChange and PctChange

from scipy import stats

window = [30, 90, 365, 1095, 1825]

def LevelChange (indicator, window): #calculate the monthly change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' change in '+str(window)+'ds']=data[indicator]-data[indicator].shift(days)
    #data[str(indicator)+' change in '+str(window)+'ds' +'zscore']=stats.zscore(data[indicator], axis=None)
    
def PctChange (indicator,window): #calculate the monthly percentage change in the indicator, window expressed in Months
    days=int(window)
    data[str(indicator)+' %change in '+str(window)+'ds']=data[indicator]/data[indicator].shift(days)-1
    #data[str(indicator)+' change in '+str(window)+'ds' +'zscore']=stats.zscore(data[indicator], axis=None)
    
def Zscore (indicator,window):  # calculate a Z score over a number of trading days
    mean=data[indicator].rolling(window).mean()
    std=data[indicator].rolling(window).std()
    data[str(indicator)+str(window)+'zscore']=(data[indicator]-mean)/std

# %%
cols = list(data.columns)

for i in window:
    for col in cols:
        Zscore (col,i)

# %%
for i in window:
    LevelChange('FDTR Index', i)
    LevelChange('CPI YOY Index', i)
    LevelChange('IP CHNG Index', i)
    LevelChange('MGT2TB Index', i)
    LevelChange('NAPMPMI Index', i)
    LevelChange('OUTFGAF Index', i)
    LevelChange('USGGBE10 Index', i)
    LevelChange('USHBMIDX Index', i)
    LevelChange('CONCCONF Index', i)
    LevelChange('OEUSKLAR Index', i)
    LevelChange('FDDSGDP Index', i)
    LevelChange('M2% YOY Index', i)
    LevelChange('CONSSENT Index', i)
    LevelChange('PIDSDPS Index', i)
    LevelChange('CICRTOT Index', i)
    LevelChange('M1% YOY Index', i)
    LevelChange('SCGRRAI Index', i)
    LevelChange('LEI CHNG Index', i)
    LevelChange('GDP CYOY Index', i)
    LevelChange('GFSIFFND Index', i)
    LevelChange('CDX HY CDSI GEN 5Y SPRD Corp', i)
    LevelChange('PCUSEQTR Index', i)
    LevelChange('GFSIRLIQ Index', i)
    LevelChange('CIGMEMRA Index', i)
    LevelChange('CIGMGRAM Index', i)
    LevelChange('LF98OAS Index', i)
    LevelChange('USGG10YR Index',i)
    LevelChange('USGG30YR Index',i)
    LevelChange('USGG5YR Index',i)
    LevelChange('USYC2Y10 Index',i)
    LevelChange('USYC2Y30 Index',i)
    LevelChange('USYC5Y10 Index',i)
    LevelChange('USYC2Y5Y Index',i)

# %%
for i in window:
    PctChange('VIX Index',i)
    PctChange('USTW$ Index',i)
    PctChange('FDIDFDMO Index',i)
    PctChange('USEMNCHG Index',i)
    PctChange('MTIBCHNG Index',i)
    PctChange('PIDSPINX Index',i)
    PctChange('RSTAMOM Index',i)
    PctChange('USTBTOT Index',i)
    PctChange('CLA Comdty',i)
    PctChange('ARDIMOYY Index',i)
    PctChange('EMB US Equity',i)
    PctChange('SPE AUTO Index',i)
    PctChange('SPE CARD Index',i)
    PctChange('BFCIUS Index',i)
    PctChange('INJCJMOM Index',i)
    PctChange('SLDETIGT Index',i)
    PctChange('SLDETGTS Index',i)
    PctChange('XLF US Equity',i)
    PctChange('XLE US Equity',i)
    PctChange('XLK US Equity',i)
    PctChange('XLV US Equity',i)
    PctChange('XLI US Equity',i)
    PctChange('XLY US Equity',i)
    PctChange('XLB US Equity',i)

# %%
data.head(2)
# Out:
#             FDTR Index  VIX Index  USTW$ Index  USGG10YR Index  \
# Date
# 1997-01-01        5.25      20.92      88.4869           6.420
# 1997-01-02        5.25      21.14      88.7042           6.514
#
#             USGG30YR Index  USGG5YR Index  USYC2Y10 Index  USYC2Y30 Index  \
# Date
# 1997-01-01           6.641           6.21           48.45            70.6
# 1997-01-02           6.739           6.28           57.80            70.5
#
#             USYC5Y10 Index  USYC2Y5Y Index  CPI YOY Index  FDIDFDMO Index  \
# Date
# 1997-01-01           14.00           34.45            0.0             0.0
# 1997-01-02           24.85           32.95            0.0             0.0
#
#             USURTOT Index  NFP TCH Index  USEMNCHG Index  IP CHNG Index  \
# Date
# 1997-01-01            0.0            0.0             0.0            0.0
# 1997-01-02            0.0            0.0             0.0            0.0
#
#             MTIBCHNG Index  MGT2TB Index  PIDSPINX Index  NAPMPMI Index  \
# Date
# 1997-01-01             0.0           0.0          7496.1           55.2
# 1997-01-02             0.0           0.0          7496.1           55.2
#
#             OUTFGAF Index  USGGBE10 Index  USHBMIDX Index  CONCCONF Index  \
# Date
# 1997-01-01            0.0             0.0             0.0             0.0
# 1997-01-02            0.0             0.0             0.0             0.0
#
#             OEUSKLAR Index  RSTAMOM Index  USTBTOT Index  FDDSGDP Index  \
# Date
# 1997-01-01         73.0712            0.0            0.0           -1.3
# 1997-01-02         73.0712            0.0            0.0           -1.3
#
#             M2% YOY Index  CLA Comdty  CONSSENT Index  PIDSDPS Index  \
# Date
# 1997-01-01            4.9         0.0             0.0            5.7
# 1997-01-02            4.9         0.0             0.0            5.7
#
#             CICRTOT Index  ARDIMOYY Index  M1% YOY Index  SCGRRAI Index  \
# Date
# 1997-01-01            0.0            4.02           -4.1            0.0
# 1997-01-02            0.0            4.02           -4.1            0.0
#
#             EMB US Equity  SPE AUTO Index  SPE CARD Index  BFCIUS Index  \
# Date
# 1997-01-01            0.0             0.0             0.0         0.779
# 1997-01-02            0.0             0.0             0.0         0.792
#
#             INJCJMOM Index  LEI CHNG Index  GDP CYOY Index  SLDETIGT Index  \
# Date
# 1997-01-01             7.5             0.1             0.0             0.0
# 1997-01-02             7.5             0.1             0.0             0.0
#
#             SLDETGTS Index  GFSIFFND Index  XLF US Equity  XLE US Equity  \
# Date
# 1997-01-01             0.0             0.0            0.0            0.0
# 1997-01-02             0.0             0.0            0.0            0.0
#
#             XLK US Equity  XLV US Equity  XLI US Equity  XLY US Equity  \
# Date
# 1997-01-01            0.0            0.0            0.0            0.0
# 1997-01-02            0.0            0.0            0.0            0.0
#
#             XLB US Equity  CDX HY CDSI GEN 5Y SPRD Corp  PCUSEQTR Index  \
# Date
# 1997-01-01            0.0                           0.0             0.0
# 1997-01-02            0.0                           0.0             0.0
#
#             GFSIRLIQ Index  CIGMEMRA Index  CIGMGRAM Index  LF98OAS Index  \
# Date
# 1997-01-01             0.0             0.0             0.0           2.88
# 1997-01-02             0.0             0.0             0.0           2.88
#
#             FDTR Index30zscore  VIX Index30zscore  USTW$ Index30zscore  \
# Date
# 1997-01-01                 NaN                NaN                  NaN
# 1997-01-02                 NaN                NaN                  NaN
#
#             USGG10YR Index30zscore  USGG30YR Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             USGG5YR Index30zscore  USYC2Y10 Index30zscore  \
# Date
# 1997-01-01                    NaN                     NaN
# 1997-01-02                    NaN                     NaN
#
#             USYC2Y30 Index30zscore  USYC5Y10 Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             USYC2Y5Y Index30zscore  CPI YOY Index30zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             FDIDFDMO Index30zscore  USURTOT Index30zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             NFP TCH Index30zscore  USEMNCHG Index30zscore  \
# Date
# 1997-01-01                    NaN                     NaN
# 1997-01-02                    NaN                     NaN
#
#             IP CHNG Index30zscore  MTIBCHNG Index30zscore  \
# Date
# 1997-01-01                    NaN                     NaN
# 1997-01-02                    NaN                     NaN
#
#             MGT2TB Index30zscore  PIDSPINX Index30zscore  \
# Date
# 1997-01-01                   NaN                     NaN
# 1997-01-02                   NaN                     NaN
#
#             NAPMPMI Index30zscore  OUTFGAF Index30zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             USGGBE10 Index30zscore  USHBMIDX Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             CONCCONF Index30zscore  OEUSKLAR Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             RSTAMOM Index30zscore  USTBTOT Index30zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             FDDSGDP Index30zscore  M2% YOY Index30zscore  CLA Comdty30zscore  \
# Date
# 1997-01-01                    NaN                    NaN                 NaN
# 1997-01-02                    NaN                    NaN                 NaN
#
#             CONSSENT Index30zscore  PIDSDPS Index30zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             CICRTOT Index30zscore  ARDIMOYY Index30zscore  \
# Date
# 1997-01-01                    NaN                     NaN
# 1997-01-02                    NaN                     NaN
#
#             M1% YOY Index30zscore  SCGRRAI Index30zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             EMB US Equity30zscore  SPE AUTO Index30zscore  \
# Date
# 1997-01-01                    NaN                     NaN
# 1997-01-02                    NaN                     NaN
#
#             SPE CARD Index30zscore  BFCIUS Index30zscore  \
# Date
# 1997-01-01                     NaN                   NaN
# 1997-01-02                     NaN                   NaN
#
#             INJCJMOM Index30zscore  LEI CHNG Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             GDP CYOY Index30zscore  SLDETIGT Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             SLDETGTS Index30zscore  GFSIFFND Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             XLF US Equity30zscore  XLE US Equity30zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             XLK US Equity30zscore  XLV US Equity30zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             XLI US Equity30zscore  XLY US Equity30zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             XLB US Equity30zscore  CDX HY CDSI GEN 5Y SPRD Corp30zscore  \
# Date
# 1997-01-01                    NaN                                   NaN
# 1997-01-02                    NaN                                   NaN
#
#             PCUSEQTR Index30zscore  GFSIRLIQ Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             CIGMEMRA Index30zscore  CIGMGRAM Index30zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             LF98OAS Index30zscore  FDTR Index90zscore  VIX Index90zscore  \
# Date
# 1997-01-01                    NaN                 NaN                NaN
# 1997-01-02                    NaN                 NaN                NaN
#
#             USTW$ Index90zscore  USGG10YR Index90zscore  \
# Date
# 1997-01-01                  NaN                     NaN
# 1997-01-02                  NaN                     NaN
#
#             USGG30YR Index90zscore  USGG5YR Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             USYC2Y10 Index90zscore  USYC2Y30 Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             USYC5Y10 Index90zscore  USYC2Y5Y Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             CPI YOY Index90zscore  FDIDFDMO Index90zscore  \
# Date
# 1997-01-01                    NaN                     NaN
# 1997-01-02                    NaN                     NaN
#
#             USURTOT Index90zscore  NFP TCH Index90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             USEMNCHG Index90zscore  IP CHNG Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             MTIBCHNG Index90zscore  MGT2TB Index90zscore  \
# Date
# 1997-01-01                     NaN                   NaN
# 1997-01-02                     NaN                   NaN
#
#             PIDSPINX Index90zscore  NAPMPMI Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             OUTFGAF Index90zscore  USGGBE10 Index90zscore  \
# Date
# 1997-01-01                    NaN                     NaN
# 1997-01-02                    NaN                     NaN
#
#             USHBMIDX Index90zscore  CONCCONF Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             OEUSKLAR Index90zscore  RSTAMOM Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             USTBTOT Index90zscore  FDDSGDP Index90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             M2% YOY Index90zscore  CLA Comdty90zscore  CONSSENT Index90zscore  \
# Date
# 1997-01-01                    NaN                 NaN                     NaN
# 1997-01-02                    NaN                 NaN                     NaN
#
#             PIDSDPS Index90zscore  CICRTOT Index90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             ARDIMOYY Index90zscore  M1% YOY Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             SCGRRAI Index90zscore  EMB US Equity90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             SPE AUTO Index90zscore  SPE CARD Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             BFCIUS Index90zscore  INJCJMOM Index90zscore  \
# Date
# 1997-01-01                   NaN                     NaN
# 1997-01-02                   NaN                     NaN
#
#             LEI CHNG Index90zscore  GDP CYOY Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             SLDETIGT Index90zscore  SLDETGTS Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             GFSIFFND Index90zscore  XLF US Equity90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             XLE US Equity90zscore  XLK US Equity90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             XLV US Equity90zscore  XLI US Equity90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             XLY US Equity90zscore  XLB US Equity90zscore  \
# Date
# 1997-01-01                    NaN                    NaN
# 1997-01-02                    NaN                    NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp90zscore  PCUSEQTR Index90zscore  \
# Date
# 1997-01-01                                   NaN                     NaN
# 1997-01-02                                   NaN                     NaN
#
#             GFSIRLIQ Index90zscore  CIGMEMRA Index90zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             CIGMGRAM Index90zscore  LF98OAS Index90zscore  \
# Date
# 1997-01-01                     NaN                    NaN
# 1997-01-02                     NaN                    NaN
#
#             FDTR Index365zscore  VIX Index365zscore  USTW$ Index365zscore  \
# Date
# 1997-01-01                  NaN                 NaN                   NaN
# 1997-01-02                  NaN                 NaN                   NaN
#
#             USGG10YR Index365zscore  USGG30YR Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             USGG5YR Index365zscore  USYC2Y10 Index365zscore  \
# Date
# 1997-01-01                     NaN                      NaN
# 1997-01-02                     NaN                      NaN
#
#             USYC2Y30 Index365zscore  USYC5Y10 Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             USYC2Y5Y Index365zscore  CPI YOY Index365zscore  \
# Date
# 1997-01-01                      NaN                     NaN
# 1997-01-02                      NaN                     NaN
#
#             FDIDFDMO Index365zscore  USURTOT Index365zscore  \
# Date
# 1997-01-01                      NaN                     NaN
# 1997-01-02                      NaN                     NaN
#
#             NFP TCH Index365zscore  USEMNCHG Index365zscore  \
# Date
# 1997-01-01                     NaN                      NaN
# 1997-01-02                     NaN                      NaN
#
#             IP CHNG Index365zscore  MTIBCHNG Index365zscore  \
# Date
# 1997-01-01                     NaN                      NaN
# 1997-01-02                     NaN                      NaN
#
#             MGT2TB Index365zscore  PIDSPINX Index365zscore  \
# Date
# 1997-01-01                    NaN                      NaN
# 1997-01-02                    NaN                      NaN
#
#             NAPMPMI Index365zscore  OUTFGAF Index365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             USGGBE10 Index365zscore  USHBMIDX Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             CONCCONF Index365zscore  OEUSKLAR Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             RSTAMOM Index365zscore  USTBTOT Index365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             FDDSGDP Index365zscore  M2% YOY Index365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             CLA Comdty365zscore  CONSSENT Index365zscore  \
# Date
# 1997-01-01                  NaN                      NaN
# 1997-01-02                  NaN                      NaN
#
#             PIDSDPS Index365zscore  CICRTOT Index365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             ARDIMOYY Index365zscore  M1% YOY Index365zscore  \
# Date
# 1997-01-01                      NaN                     NaN
# 1997-01-02                      NaN                     NaN
#
#             SCGRRAI Index365zscore  EMB US Equity365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             SPE AUTO Index365zscore  SPE CARD Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             BFCIUS Index365zscore  INJCJMOM Index365zscore  \
# Date
# 1997-01-01                    NaN                      NaN
# 1997-01-02                    NaN                      NaN
#
#             LEI CHNG Index365zscore  GDP CYOY Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             SLDETIGT Index365zscore  SLDETGTS Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             GFSIFFND Index365zscore  XLF US Equity365zscore  \
# Date
# 1997-01-01                      NaN                     NaN
# 1997-01-02                      NaN                     NaN
#
#             XLE US Equity365zscore  XLK US Equity365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             XLV US Equity365zscore  XLI US Equity365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             XLY US Equity365zscore  XLB US Equity365zscore  \
# Date
# 1997-01-01                     NaN                     NaN
# 1997-01-02                     NaN                     NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp365zscore  PCUSEQTR Index365zscore  \
# Date
# 1997-01-01                                    NaN                      NaN
# 1997-01-02                                    NaN                      NaN
#
#             GFSIRLIQ Index365zscore  CIGMEMRA Index365zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             CIGMGRAM Index365zscore  LF98OAS Index365zscore  \
# Date
# 1997-01-01                      NaN                     NaN
# 1997-01-02                      NaN                     NaN
#
#             FDTR Index1095zscore  VIX Index1095zscore  USTW$ Index1095zscore  \
# Date
# 1997-01-01                   NaN                  NaN                    NaN
# 1997-01-02                   NaN                  NaN                    NaN
#
#             USGG10YR Index1095zscore  USGG30YR Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             USGG5YR Index1095zscore  USYC2Y10 Index1095zscore  \
# Date
# 1997-01-01                      NaN                       NaN
# 1997-01-02                      NaN                       NaN
#
#             USYC2Y30 Index1095zscore  USYC5Y10 Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             USYC2Y5Y Index1095zscore  CPI YOY Index1095zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             FDIDFDMO Index1095zscore  USURTOT Index1095zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             NFP TCH Index1095zscore  USEMNCHG Index1095zscore  \
# Date
# 1997-01-01                      NaN                       NaN
# 1997-01-02                      NaN                       NaN
#
#             IP CHNG Index1095zscore  MTIBCHNG Index1095zscore  \
# Date
# 1997-01-01                      NaN                       NaN
# 1997-01-02                      NaN                       NaN
#
#             MGT2TB Index1095zscore  PIDSPINX Index1095zscore  \
# Date
# 1997-01-01                     NaN                       NaN
# 1997-01-02                     NaN                       NaN
#
#             NAPMPMI Index1095zscore  OUTFGAF Index1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             USGGBE10 Index1095zscore  USHBMIDX Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             CONCCONF Index1095zscore  OEUSKLAR Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             RSTAMOM Index1095zscore  USTBTOT Index1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             FDDSGDP Index1095zscore  M2% YOY Index1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             CLA Comdty1095zscore  CONSSENT Index1095zscore  \
# Date
# 1997-01-01                   NaN                       NaN
# 1997-01-02                   NaN                       NaN
#
#             PIDSDPS Index1095zscore  CICRTOT Index1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             ARDIMOYY Index1095zscore  M1% YOY Index1095zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             SCGRRAI Index1095zscore  EMB US Equity1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             SPE AUTO Index1095zscore  SPE CARD Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             BFCIUS Index1095zscore  INJCJMOM Index1095zscore  \
# Date
# 1997-01-01                     NaN                       NaN
# 1997-01-02                     NaN                       NaN
#
#             LEI CHNG Index1095zscore  GDP CYOY Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             SLDETIGT Index1095zscore  SLDETGTS Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             GFSIFFND Index1095zscore  XLF US Equity1095zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             XLE US Equity1095zscore  XLK US Equity1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             XLV US Equity1095zscore  XLI US Equity1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             XLY US Equity1095zscore  XLB US Equity1095zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp1095zscore  PCUSEQTR Index1095zscore  \
# Date
# 1997-01-01                                     NaN                       NaN
# 1997-01-02                                     NaN                       NaN
#
#             GFSIRLIQ Index1095zscore  CIGMEMRA Index1095zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             CIGMGRAM Index1095zscore  LF98OAS Index1095zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             FDTR Index1825zscore  VIX Index1825zscore  USTW$ Index1825zscore  \
# Date
# 1997-01-01                   NaN                  NaN                    NaN
# 1997-01-02                   NaN                  NaN                    NaN
#
#             USGG10YR Index1825zscore  USGG30YR Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             USGG5YR Index1825zscore  USYC2Y10 Index1825zscore  \
# Date
# 1997-01-01                      NaN                       NaN
# 1997-01-02                      NaN                       NaN
#
#             USYC2Y30 Index1825zscore  USYC5Y10 Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             USYC2Y5Y Index1825zscore  CPI YOY Index1825zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             FDIDFDMO Index1825zscore  USURTOT Index1825zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             NFP TCH Index1825zscore  USEMNCHG Index1825zscore  \
# Date
# 1997-01-01                      NaN                       NaN
# 1997-01-02                      NaN                       NaN
#
#             IP CHNG Index1825zscore  MTIBCHNG Index1825zscore  \
# Date
# 1997-01-01                      NaN                       NaN
# 1997-01-02                      NaN                       NaN
#
#             MGT2TB Index1825zscore  PIDSPINX Index1825zscore  \
# Date
# 1997-01-01                     NaN                       NaN
# 1997-01-02                     NaN                       NaN
#
#             NAPMPMI Index1825zscore  OUTFGAF Index1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             USGGBE10 Index1825zscore  USHBMIDX Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             CONCCONF Index1825zscore  OEUSKLAR Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             RSTAMOM Index1825zscore  USTBTOT Index1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             FDDSGDP Index1825zscore  M2% YOY Index1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             CLA Comdty1825zscore  CONSSENT Index1825zscore  \
# Date
# 1997-01-01                   NaN                       NaN
# 1997-01-02                   NaN                       NaN
#
#             PIDSDPS Index1825zscore  CICRTOT Index1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             ARDIMOYY Index1825zscore  M1% YOY Index1825zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             SCGRRAI Index1825zscore  EMB US Equity1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             SPE AUTO Index1825zscore  SPE CARD Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             BFCIUS Index1825zscore  INJCJMOM Index1825zscore  \
# Date
# 1997-01-01                     NaN                       NaN
# 1997-01-02                     NaN                       NaN
#
#             LEI CHNG Index1825zscore  GDP CYOY Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             SLDETIGT Index1825zscore  SLDETGTS Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             GFSIFFND Index1825zscore  XLF US Equity1825zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             XLE US Equity1825zscore  XLK US Equity1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             XLV US Equity1825zscore  XLI US Equity1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             XLY US Equity1825zscore  XLB US Equity1825zscore  \
# Date
# 1997-01-01                      NaN                      NaN
# 1997-01-02                      NaN                      NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp1825zscore  PCUSEQTR Index1825zscore  \
# Date
# 1997-01-01                                     NaN                       NaN
# 1997-01-02                                     NaN                       NaN
#
#             GFSIRLIQ Index1825zscore  CIGMEMRA Index1825zscore  \
# Date
# 1997-01-01                       NaN                       NaN
# 1997-01-02                       NaN                       NaN
#
#             CIGMGRAM Index1825zscore  LF98OAS Index1825zscore  \
# Date
# 1997-01-01                       NaN                      NaN
# 1997-01-02                       NaN                      NaN
#
#             FDTR Index change in 30ds  CPI YOY Index change in 30ds  \
# Date
# 1997-01-01                        NaN                           NaN
# 1997-01-02                        NaN                           NaN
#
#             IP CHNG Index change in 30ds  MGT2TB Index change in 30ds  \
# Date
# 1997-01-01                           NaN                          NaN
# 1997-01-02                           NaN                          NaN
#
#             NAPMPMI Index change in 30ds  OUTFGAF Index change in 30ds  \
# Date
# 1997-01-01                           NaN                           NaN
# 1997-01-02                           NaN                           NaN
#
#             USGGBE10 Index change in 30ds  USHBMIDX Index change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             CONCCONF Index change in 30ds  OEUSKLAR Index change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             FDDSGDP Index change in 30ds  M2% YOY Index change in 30ds  \
# Date
# 1997-01-01                           NaN                           NaN
# 1997-01-02                           NaN                           NaN
#
#             CONSSENT Index change in 30ds  PIDSDPS Index change in 30ds  \
# Date
# 1997-01-01                            NaN                           NaN
# 1997-01-02                            NaN                           NaN
#
#             CICRTOT Index change in 30ds  M1% YOY Index change in 30ds  \
# Date
# 1997-01-01                           NaN                           NaN
# 1997-01-02                           NaN                           NaN
#
#             SCGRRAI Index change in 30ds  LEI CHNG Index change in 30ds  \
# Date
# 1997-01-01                           NaN                            NaN
# 1997-01-02                           NaN                            NaN
#
#             GDP CYOY Index change in 30ds  GFSIFFND Index change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             CDX HY CDSI GEN 5Y SPRD Corp change in 30ds  \
# Date
# 1997-01-01                                          NaN
# 1997-01-02                                          NaN
#
#             PCUSEQTR Index change in 30ds  GFSIRLIQ Index change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             CIGMEMRA Index change in 30ds  CIGMGRAM Index change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             LF98OAS Index change in 30ds  USGG10YR Index change in 30ds  \
# Date
# 1997-01-01                           NaN                            NaN
# 1997-01-02                           NaN                            NaN
#
#             USGG30YR Index change in 30ds  USGG5YR Index change in 30ds  \
# Date
# 1997-01-01                            NaN                           NaN
# 1997-01-02                            NaN                           NaN
#
#             USYC2Y10 Index change in 30ds  USYC2Y30 Index change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             USYC5Y10 Index change in 30ds  USYC2Y5Y Index change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             FDTR Index change in 90ds  CPI YOY Index change in 90ds  \
# Date
# 1997-01-01                        NaN                           NaN
# 1997-01-02                        NaN                           NaN
#
#             IP CHNG Index change in 90ds  MGT2TB Index change in 90ds  \
# Date
# 1997-01-01                           NaN                          NaN
# 1997-01-02                           NaN                          NaN
#
#             NAPMPMI Index change in 90ds  OUTFGAF Index change in 90ds  \
# Date
# 1997-01-01                           NaN                           NaN
# 1997-01-02                           NaN                           NaN
#
#             USGGBE10 Index change in 90ds  USHBMIDX Index change in 90ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             CONCCONF Index change in 90ds  OEUSKLAR Index change in 90ds  \
# Date
# ...
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             XLY US Equity %change in 30ds  XLB US Equity %change in 30ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             VIX Index %change in 90ds  USTW$ Index %change in 90ds  \
# Date
# 1997-01-01                        NaN                          NaN
# 1997-01-02                        NaN                          NaN
#
#             FDIDFDMO Index %change in 90ds  USEMNCHG Index %change in 90ds  \
# Date
# 1997-01-01                             NaN                             NaN
# 1997-01-02                             NaN                             NaN
#
#             MTIBCHNG Index %change in 90ds  PIDSPINX Index %change in 90ds  \
# Date
# 1997-01-01                             NaN                             NaN
# 1997-01-02                             NaN                             NaN
#
#             RSTAMOM Index %change in 90ds  USTBTOT Index %change in 90ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             CLA Comdty %change in 90ds  ARDIMOYY Index %change in 90ds  \
# Date
# 1997-01-01                         NaN                             NaN
# 1997-01-02                         NaN                             NaN
#
#             EMB US Equity %change in 90ds  SPE AUTO Index %change in 90ds  \
# Date
# 1997-01-01                            NaN                             NaN
# 1997-01-02                            NaN                             NaN
#
#             SPE CARD Index %change in 90ds  BFCIUS Index %change in 90ds  \
# Date
# 1997-01-01                             NaN                           NaN
# 1997-01-02                             NaN                           NaN
#
#             INJCJMOM Index %change in 90ds  SLDETIGT Index %change in 90ds  \
# Date
# 1997-01-01                             NaN                             NaN
# 1997-01-02                             NaN                             NaN
#
#             SLDETGTS Index %change in 90ds  XLF US Equity %change in 90ds  \
# Date
# 1997-01-01                             NaN                            NaN
# 1997-01-02                             NaN                            NaN
#
#             XLE US Equity %change in 90ds  XLK US Equity %change in 90ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             XLV US Equity %change in 90ds  XLI US Equity %change in 90ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             XLY US Equity %change in 90ds  XLB US Equity %change in 90ds  \
# Date
# 1997-01-01                            NaN                            NaN
# 1997-01-02                            NaN                            NaN
#
#             VIX Index %change in 365ds  USTW$ Index %change in 365ds  \
# Date
# 1997-01-01                         NaN                           NaN
# 1997-01-02                         NaN                           NaN
#
#             FDIDFDMO Index %change in 365ds  USEMNCHG Index %change in 365ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             MTIBCHNG Index %change in 365ds  PIDSPINX Index %change in 365ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             RSTAMOM Index %change in 365ds  USTBTOT Index %change in 365ds  \
# Date
# 1997-01-01                             NaN                             NaN
# 1997-01-02                             NaN                             NaN
#
#             CLA Comdty %change in 365ds  ARDIMOYY Index %change in 365ds  \
# Date
# 1997-01-01                          NaN                              NaN
# 1997-01-02                          NaN                              NaN
#
#             EMB US Equity %change in 365ds  SPE AUTO Index %change in 365ds  \
# Date
# 1997-01-01                             NaN                              NaN
# 1997-01-02                             NaN                              NaN
#
#             SPE CARD Index %change in 365ds  BFCIUS Index %change in 365ds  \
# Date
# 1997-01-01                              NaN                            NaN
# 1997-01-02                              NaN                            NaN
#
#             INJCJMOM Index %change in 365ds  SLDETIGT Index %change in 365ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             SLDETGTS Index %change in 365ds  XLF US Equity %change in 365ds  \
# Date
# 1997-01-01                              NaN                             NaN
# 1997-01-02                              NaN                             NaN
#
#             XLE US Equity %change in 365ds  XLK US Equity %change in 365ds  \
# Date
# 1997-01-01                             NaN                             NaN
# 1997-01-02                             NaN                             NaN
#
#             XLV US Equity %change in 365ds  XLI US Equity %change in 365ds  \
# Date
# 1997-01-01                             NaN                             NaN
# 1997-01-02                             NaN                             NaN
#
#             XLY US Equity %change in 365ds  XLB US Equity %change in 365ds  \
# Date
# 1997-01-01                             NaN                             NaN
# 1997-01-02                             NaN                             NaN
#
#             VIX Index %change in 1095ds  USTW$ Index %change in 1095ds  \
# Date
# 1997-01-01                          NaN                            NaN
# 1997-01-02                          NaN                            NaN
#
#             FDIDFDMO Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             USEMNCHG Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             MTIBCHNG Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             PIDSPINX Index %change in 1095ds  RSTAMOM Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN                              NaN
# 1997-01-02                               NaN                              NaN
#
#             USTBTOT Index %change in 1095ds  CLA Comdty %change in 1095ds  \
# Date
# 1997-01-01                              NaN                           NaN
# 1997-01-02                              NaN                           NaN
#
#             ARDIMOYY Index %change in 1095ds  EMB US Equity %change in 1095ds  \
# Date
# 1997-01-01                               NaN                              NaN
# 1997-01-02                               NaN                              NaN
#
#             SPE AUTO Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             SPE CARD Index %change in 1095ds  BFCIUS Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN                             NaN
# 1997-01-02                               NaN                             NaN
#
#             INJCJMOM Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             SLDETIGT Index %change in 1095ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             SLDETGTS Index %change in 1095ds  XLF US Equity %change in 1095ds  \
# Date
# 1997-01-01                               NaN                              NaN
# 1997-01-02                               NaN                              NaN
#
#             XLE US Equity %change in 1095ds  XLK US Equity %change in 1095ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             XLV US Equity %change in 1095ds  XLI US Equity %change in 1095ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             XLY US Equity %change in 1095ds  XLB US Equity %change in 1095ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             VIX Index %change in 1825ds  USTW$ Index %change in 1825ds  \
# Date
# 1997-01-01                          NaN                            NaN
# 1997-01-02                          NaN                            NaN
#
#             FDIDFDMO Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             USEMNCHG Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             MTIBCHNG Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             PIDSPINX Index %change in 1825ds  RSTAMOM Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN                              NaN
# 1997-01-02                               NaN                              NaN
#
#             USTBTOT Index %change in 1825ds  CLA Comdty %change in 1825ds  \
# Date
# 1997-01-01                              NaN                           NaN
# 1997-01-02                              NaN                           NaN
#
#             ARDIMOYY Index %change in 1825ds  EMB US Equity %change in 1825ds  \
# Date
# 1997-01-01                               NaN                              NaN
# 1997-01-02                               NaN                              NaN
#
#             SPE AUTO Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             SPE CARD Index %change in 1825ds  BFCIUS Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN                             NaN
# 1997-01-02                               NaN                             NaN
#
#             INJCJMOM Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             SLDETIGT Index %change in 1825ds  \
# Date
# 1997-01-01                               NaN
# 1997-01-02                               NaN
#
#             SLDETGTS Index %change in 1825ds  XLF US Equity %change in 1825ds  \
# Date
# 1997-01-01                               NaN                              NaN
# 1997-01-02                               NaN                              NaN
#
#             XLE US Equity %change in 1825ds  XLK US Equity %change in 1825ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             XLV US Equity %change in 1825ds  XLI US Equity %change in 1825ds  \
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN
#
#             XLY US Equity %change in 1825ds  XLB US Equity %change in 1825ds
# Date
# 1997-01-01                              NaN                              NaN
# 1997-01-02                              NaN                              NaN

# %%
# Transform target variable into binary classification

data['LF98OAS Index change in 30ds'] = [1 if i >= 0.5 else 0 for i in data['LF98OAS Index change in 30ds']]
 
data['LF98OAS Index change in 30ds'].value_counts()
# Out:
# 0    6473
# 1    1101
# Name: LF98OAS Index change in 30ds, dtype: int64

# %% [markdown]
# **Plot the classes**

# %%
plt.hist(data['LF98OAS Index change in 30ds'], bins=range(0,3), rwidth=0.8, color='cadetblue')

plt.xlabel(('No jump event vs. jump event'))
plt.xticks([])
# Out:
# ([], <a list of 0 Text xticklabel objects>)

# %% [markdown]
# *This is an imbalanced dataset - resampling is required.*

# %% [markdown]
# **Define input and target variables**

# %%
y = data['LF98OAS Index change in 30ds'].fillna(0)

#30, 90, 365, 1095, 1825
#LF98OAS Index
#LF98OAS Index90zscore
#LF98OAS Index180zscore
#LF98OAS Index360zscore
#LF98OAS Index change in 90dszscore
#LF98OAS Index change in 180dszscore
#LF98OAS Index change in 360dszscore

X = data.drop(['LF98OAS Index', 'LF98OAS Index change in 30ds','LF98OAS Index change in 90ds',\
          'LF98OAS Index change in 365ds', 'LF98OAS Index change in 1095ds',\
          'LF98OAS Index change in 1825ds','LF98OAS Index30zscore','LF98OAS Index90zscore',\
          'LF98OAS Index365zscore', 'LF98OAS Index1095zscore', 'LF98OAS Index1825zscore'], axis=1)

# %%
#check if X contains any column related to target variable

cols = list(X.columns)

for col in cols:
    if "LF98OAS" in col:
        print (col)

# %% [markdown]
# **Calculate class weights**

# %%
naive=data['LF98OAS Index change in 30ds'].value_counts()# naive prediction
print(naive)
data['LF98OAS Index change in 30ds'].plot(color='cadetblue')
# Out:
# 0    6473
# 1    1101
# Name: LF98OAS Index change in 30ds, dtype: int64

# %%
def weight(cl):
    if cl==1:
        return naive[0].astype(float)/naive[1].astype(float)
    else:
        return 1

wgt = y.apply(weight)

# %%
wgt.value_counts()
# Out:
# 1.000000    6473
# 5.879201    1101
# Name: LF98OAS Index change in 30ds, dtype: int64

# %%
#address inf and nan values
X = X.replace([np.inf, -np.inf], np.nan).fillna(0)

# %%
#split out training and testing sets

X_train = X[:6015]
y_train = y[:6015]
X_test = X[6015:]
y_test = y[6015:]
y_test.describe()
# Out:
# count    1559.000000
# mean        0.108403
# std         0.310988
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: LF98OAS Index change in 30ds, dtype: float64

# %% [markdown]
# **Gradient Boosted Trees**

# %%
#try Gradient Boosted Trees

from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score

# tuning the number of leaves
group = []
for i in np.linspace(10,20,num=11):
    i=int(i)
    params = {'n_estimators': 5000, 'max_depth': 30, 'max_features': 0.7,
          'learning_rate': 0.01, 'max_leaf_nodes': i, 'random_state': 47}

    gbc = GradientBoostingClassifier(**params)

    gbc.fit(X_train, y_train,sample_weight=wgt[:6015])

    scores = cross_val_score(gbc, X_train, y_train, cv=5, scoring='roc_auc')
    group.append((i, roc_auc_score(y_test, gbc.predict(X_test)),
                  roc_auc_score(y_train, gbc.predict(X_train)),
                  scores.mean(), scores.std()))

# %%
print(group)

# %%
group_results = pd.DataFrame(data=group)
group_results.columns = ['max_leaf_nodes','Test auc score','Train auc score','Average cross validation auc score','Std cross validation']
group_results = group_results.set_index('N_estimators')

group_results.plot()

# %%
feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(X_test.columns, gbc.feature_importances_):
    feats[feature] = importance #add the name/value pair 

importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Importance'})
importances = importances[:20]
importances.sort_values(by='Importance', ascending=False).plot(kind='bar', rot=90, color=color)

# %%
average_precision = average_precision_score(y_test, gbc.predict(X_test))

print('Average precision-recall score: {0:0.2f}'.format(average_precision))

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, _ = precision_recall_curve(y_test, gbc.predict(X_test))

plt.step(recall, precision, color='b', alpha=0.2,
         where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2,
                 color='seagreen')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision))

# %% [markdown]
# Precision-Recall is a useful measure of success of prediction when the classes are very imbalanced. In information retrieval, precision is a measure of result relevancy, while recall is a measure of how many truly relevant results are returned.
#
# The precision-recall curve shows the tradeoff between precision and recall for different threshold. A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).
#
# A system with high recall but low precision returns many results, but most of its predicted labels are incorrect when compared to the training labels. A system with high precision but low recall is just the opposite, returning very few results, but most of its predicted labels are correct when compared to the training labels. An ideal system with high precision and high recall will return many results, with all results labeled correctly.
#
# Precision (P) is defined as the number of true positives (T_p) over the number of true positives plus the number of false positives (F_p).
#
# Precision P = TP/(TP+FP)
#
# Recall (R) is defined as the number of true positives (T_p) over the number of true positives plus the number of false negatives (F_n).
#
# Recall R = TP/(TP+FN)
#
# These quantities are also related to the (F_1) score, which is defined as the harmonic mean of precision and recall.
#
# F1 = 2x(PxR)/(P+R)
