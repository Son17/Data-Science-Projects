# %%
# import libraries

import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette()

# %%
# import data

prop = pd.read_csv('C:\\Users\\sonja tilly.ABERDEEN\\Zillow\\properties_2016.csv\\properties_2016.csv',\
                  low_memory=False)
train = pd.read_csv('C:\\Users\\sonja tilly.ABERDEEN\Zillow\\train_2016.csv\\train_2016.csv',\
                  low_memory=False)
sample = pd.read_csv('C:\\Users\\sonja tilly.ABERDEEN\\Zillow\\sample_submission.csv\\sample_submission.csv',\
                  low_memory=False)

# %%
# merge dataframes

df_train = train.merge(prop, how='left', on='parcelid')

# %%
median_values = df_train.median(axis=0)
df_train_new = df_train.fillna(median_values, inplace=True)

# %%
df_train['transactiondate'] = pd.to_datetime(df_train.transactiondate)
df_train_new['transactiondate'] = pd.to_numeric(df_train_new['transactiondate'])

# %%
#Encode columns containing object data types

from sklearn import preprocessing 

le = preprocessing.LabelEncoder()

df_train_new['hashottuborspa'] = le.fit_transform(df_train_new['hashottuborspa'])
df_train_new['fireplaceflag'] = le.fit_transform(df_train_new['fireplaceflag'])

df_train_new['propertyzoningdesc'] = df_train_new['propertyzoningdesc'].factorize()[0]
df_train_new['propertyzoningdesc'] = le.fit_transform(df_train_new['propertyzoningdesc'])

df_train_new['propertycountylandusecode'] = df_train_new['propertycountylandusecode'].factorize()[0]
df_train_new['propertycountylandusecode'] = le.fit_transform(df_train_new['propertycountylandusecode'])

df_train_new['taxdelinquencyflag'] = df_train_new['taxdelinquencyflag'].factorize()[0]
df_train_new['taxdelinquencyflag'] = le.fit_transform(df_train_new['taxdelinquencyflag'])
# Out:
# C:\Users\sonja tilly.ABERDEEN\AppData\Local\Continuum\Anaconda2\envs\py35\lib\site-packages\numpy\lib\arraysetops.py:216: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))

# %%
#df_train_new.info()
#df_train_new.drop('transactiondate', axis=1, inplace=True)
df_train_new.head()
# Out:
#    parcelid  logerror      transactiondate  airconditioningtypeid  \
# 0  11016594    0.0276  1451606400000000000                    1.0
# 1  14366692   -0.1684  1451606400000000000                    1.0
# 2  12098116   -0.0040  1451606400000000000                    1.0
# 3  12643413    0.0218  1451692800000000000                    1.0
# 4  14432541   -0.0050  1451692800000000000                    1.0
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       7.0         616.0          2.0         3.0
# 1                       7.0         616.0          3.5         4.0
# 2                       7.0         616.0          3.0         2.0
# 3                       7.0         616.0          2.0         2.0
# 4                       7.0         616.0          2.5         4.0
#
#    buildingclasstypeid  buildingqualitytypeid         ...           \
# 0                  4.0                    4.0         ...
# 1                  4.0                    7.0         ...
# 2                  4.0                    4.0         ...
# 3                  4.0                    4.0         ...
# 4                  4.0                    7.0         ...
#
#    numberofstories  fireplaceflag  structuretaxvaluedollarcnt  \
# 0              1.0              0                    122754.0
# 1              1.0            288                    346458.0
# 2              1.0            288                     61994.0
# 3              1.0            288                    171518.0
# 4              2.0            288                    169574.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           360170.0          2015.0               237416.0    6735.88
# 1           585529.0          2015.0               239071.0   10153.02
# 2           119906.0          2015.0                57912.0   11484.48
# 3           244880.0          2015.0                73362.0    3048.74
# 4           434551.0          2015.0               264977.0    5488.96
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                   0                14.0         6.037107e+13
# 1                   0                14.0         6.037615e+13
# 2                   0                14.0         6.037464e+13
# 3                   0                14.0         6.037296e+13
# 4                   0                14.0         6.059042e+13
#
# [5 rows x 60 columns]

# %%
# define predictors (X) and target (y)

#y = pd.DataFrame(data['logerror'])
y=df_train_new['logerror'].ravel()

# %%
X = df_train_new.drop('logerror', axis=1, inplace=True)
X=df_train_new.drop('transactiondate', axis=1, inplace=True)
X = df_train_new
X.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  11016594                    1.0                       7.0         616.0
# 1  14366692                    1.0                       7.0         616.0
# 2  12098116                    1.0                       7.0         616.0
# 3  12643413                    1.0                       7.0         616.0
# 4  14432541                    1.0                       7.0         616.0
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          2.0         3.0                  4.0                    4.0
# 1          3.5         4.0                  4.0                    7.0
# 2          3.0         2.0                  4.0                    4.0
# 3          2.0         2.0                  4.0                    4.0
# 4          2.5         4.0                  4.0                    7.0
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# 0                2.0        66.0         ...                       1.0
# 1                3.5        66.0         ...                       1.0
# 2                3.0        66.0         ...                       1.0
# 3                2.0        66.0         ...                       1.0
# 4                2.5        66.0         ...                       2.0
#
#    fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0              0                    122754.0           360170.0
# 1            288                    346458.0           585529.0
# 2            288                     61994.0           119906.0
# 3            288                    171518.0           244880.0
# 4            288                    169574.0           434551.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0          2015.0               237416.0    6735.88                   0
# 1          2015.0               239071.0   10153.02                   0
# 2          2015.0                57912.0   11484.48                   0
# 3          2015.0                73362.0    3048.74                   0
# 4          2015.0               264977.0    5488.96                   0
#
#    taxdelinquencyyear  censustractandblock
# 0                14.0         6.037107e+13
# 1                14.0         6.037615e+13
# 2                14.0         6.037464e+13
# 3                14.0         6.037296e+13
# 4                14.0         6.059042e+13
#
# [5 rows x 58 columns]

# %%
# split dataset

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
#Encode columns containing object data types

from sklearn import preprocessing 

le = preprocessing.LabelEncoder()

prop['hashottuborspa'] = le.fit_transform(prop['hashottuborspa'])
prop['fireplaceflag'] = le.fit_transform(prop['fireplaceflag'])

prop['propertyzoningdesc'] = prop['propertyzoningdesc'].factorize()[0]
prop['propertyzoningdesc'] = le.fit_transform(prop['propertyzoningdesc'])

prop['propertycountylandusecode'] = prop['propertycountylandusecode'].factorize()[0]
prop['propertycountylandusecode'] = le.fit_transform(prop['propertycountylandusecode'])

prop['taxdelinquencyflag'] = prop['taxdelinquencyflag'].factorize()[0]
prop['taxdelinquencyflag'] = le.fit_transform(prop['taxdelinquencyflag'])
# Out:
# C:\Users\sonja tilly.ABERDEEN\AppData\Local\Continuum\Anaconda2\envs\py35\lib\site-packages\numpy\lib\arraysetops.py:216: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))

# %%
median_values = prop.median(axis=0)
prop = prop.fillna(median_values, inplace=True)
prop.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    1.0                       7.0         534.0
# 1  10759547                    1.0                       7.0         534.0
# 2  10843547                    1.0                       7.0         534.0
# 3  10859147                    1.0                       7.0         534.0
# 4  10879947                    1.0                       7.0         534.0
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  4.0                    7.0
# 1          0.0         0.0                  4.0                    7.0
# 2          0.0         0.0                  4.0                    7.0
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    7.0
#
#    calculatedbathnbr  decktypeid         ...           numberofstories  \
# 0                2.0        66.0         ...                       1.0
# 1                2.0        66.0         ...                       1.0
# 2                2.0        66.0         ...                       1.0
# 3                2.0        66.0         ...                       1.0
# 4                2.0        66.0         ...                       1.0
#
#    fireplaceflag  structuretaxvaluedollarcnt  taxvaluedollarcnt  \
# 0              0                    122590.0                9.0
# 1           6476                    122590.0            27516.0
# 2           6476                    650756.0          1413387.0
# 3           6476                    571346.0          1156834.0
# 4           6476                    193796.0           433491.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 0          2015.0                    9.0    3991.78                   0
# 1          2015.0                27516.0    3991.78                   0
# 2          2015.0               762631.0   20800.37                   0
# 3          2015.0               585488.0   14557.57                   0
# 4          2015.0               239695.0    5725.17                   0
#
#    taxdelinquencyyear  censustractandblock
# 0                14.0         6.037572e+13
# 1                14.0         6.037572e+13
# 2                14.0         6.037572e+13
# 3                14.0         6.037572e+13
# 4                14.0         6.037572e+13
#
# [5 rows x 58 columns]

# %%
#predict on columns contained in X

prop=prop[X.columns]

# %%
# build model

from sklearn.ensemble import RandomForestRegressor

tree = RandomForestRegressor(random_state=47)
tree.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=47,
#            verbose=0, warm_start=False)

# %%
# optimise model

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer

param_grid = {'max_depth':[5,15,25,50], 'min_samples_split':[10,100,250,500], 'n_jobs':[-1], 'n_estimators':[70]}
             
scorer = make_scorer(mean_absolute_error)
    
tree_opt = GridSearchCV(tree, param_grid, cv=10, scoring=scorer)
    
tree_opt.fit(X_train, y_train)

# Get the best estimator
best_pred = tree_opt.best_estimator_

#print("The logerror on the testing data is: {:.4f}".format(scorer(y_test, best_pred)))

# %%
#Predict on prop file

pred = best_tree.predict(prop)

# %%
print("Start writing to file ...")
for c in sample.columns[sample.columns != 'ParcelId']:
    sample[c] = pred
# Out:
# Start writing to file ...

# %%
sample.to_csv('submission.csv', index=False, float_format='%.4f')
